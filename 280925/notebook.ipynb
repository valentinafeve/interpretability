# %%
import torch
from PIL import Image
from torchvision.io import read_image
from torchvision.io import ImageReadMode
import matplotlib.pyplot as plt
import numpy as np
import torch
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as datasets
from PIL import Image
from torchvision.transforms import (Compose, Normalize, Resize, ToPILImage,
                                    ToTensor)
from tqdm.notebook import tqdm, trange
import numpy as np
import logging
from matplotlib.cm import ScalarMappable
from torchvision import transforms
import torchvision
from matplotlib.colors import Normalize
import random
from datasets import load_dataset

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

import torchvision.transforms.functional as F


plt.rcParams["savefig.bbox"] = 'tight'


def show(imgs):
    if not isinstance(imgs, list):
        imgs = [imgs]
    fig, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = img.detach()
        img = F.to_pil_image(img)
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
if device == 'cpu':
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# mps

# %%
def save_tensor_as_image(tensor, filename):
    """
    Saves a single tensor as an image file.

    Args:
        tensor (torch.Tensor): A 2D tensor representing the image.
        filename (str): The path where the image will be saved.
    """
    if tensor.dim() != 2:
        raise ValueError("Input tensor must be 2D.")

    array = tensor.cpu().numpy()
    plt.imsave(filename, array, cmap='gray')

# %%
def plot_tensors(tensor, title=None, cmap="magma", show_colorbar=True, save_path=None):
    """
    Plots a batch of filters/images in a nearly square grid.

    The input tensor should have shape (batch_size, filters, height, width).
    Only the first batch element is visualized.

    Args:
        tensor (torch.Tensor or np.ndarray):
            A 4D tensor or array with shape (B, K, H, W).
        title (str, optional):
            Title for the entire grid plot. Defaults to None.
        cmap (str, optional):
            Colormap for visualization. Defaults to "magma".
        show_colorbar (bool, optional):
            Whether to display a shared colorbar. Defaults to True.
        save_path (str, optional):
            File path to save the plot. If None, the plot is not saved.

    Returns:
        None. Displays (and optionally saves) the grid of images.
    """
    if isinstance(tensor, torch.Tensor):
        tensor = tensor.detach().cpu().numpy()

    B, K, H, W = tensor.shape
    imgs = tensor[0]  # (K, H, W)

    vmin, vmax = float(imgs.min()), float(imgs.max())

    # --- cuadrado automático ---
    cols = int(np.ceil(np.sqrt(K)))
    rows = int(np.ceil(K / cols))

    fig, axs = plt.subplots(rows, cols, figsize=(cols * 2, rows * 2))
    axs = np.atleast_2d(axs)

    for i in range(K):
        r, c = divmod(i, cols)
        axs[r, c].imshow(imgs[i], cmap=cmap, vmin=vmin, vmax=vmax)
        axs[r, c].axis("off")

    # Apagar celdas sobrantes
    for j in range(K, rows * cols):
        r, c = divmod(j, cols)
        axs[r, c].axis("off")

    # Colorbar compartida
    if show_colorbar:
        cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
        norm = Normalize(vmin=vmin, vmax=vmax)
        sm = ScalarMappable(cmap=cmap, norm=norm)
        sm.set_array([])
        cbar = fig.colorbar(sm, cax=cbar_ax)
        cbar.set_ticks([vmin, vmax])

    if title:
        fig.suptitle(title, fontsize=14)

    plt.tight_layout(rect=[0, 0, 0.9, 0.95])

    if save_path:
        plt.savefig(save_path, bbox_inches="tight", dpi=150)

    plt.show()
    plt.close()

# %%
import torch

def generate_templates(n: int, tau: float = 0.5, beta: float = 4.0):
    """
    Generates n^2 positive templates and one negative template
    for an interpretable CNN, as described in Zhang et al. (2018).

    Each positive template corresponds to a potential spatial position
    in an n x n feature map. Values decay according to the L1 distance
    from the central position. A negative template is also generated
    to represent the absence of activation.

    Args:
        n (int): Size of the feature map (n x n).
        tau (float, optional): Scaling constant for maximum activation value.
            Defaults to 0.5.
        beta (float, optional): Decay factor based on L1 distance.
            Defaults to 4.0.

    Returns:
        tuple:
            templates_pos (list[torch.Tensor]): List of n^2 positive templates
                (each of shape n x n).
            template_neg (torch.Tensor): Negative template of shape n x n
                filled with -tau.

    Example:
        >>> templates_pos, template_neg = generate_templates(4)
        >>> len(templates_pos)
        16
        >>> template_neg.shape
        torch.Size([4, 4])
    """
    templates_pos = []
    coords = [(i, j) for i in range(n) for j in range(n)]

    for mu in coords:
        template = torch.zeros((n, n))
        for i in range(n):
            for j in range(n):
                dist = abs(i - mu[0]) + abs(j - mu[1])  # L1 distance
                value = tau * max(1 - beta * dist / n, -1)
                template[i, j] = value
        templates_pos.append(template)

    template_neg = torch.full((n, n), -tau)

    templates = torch.stack(templates_pos + [template_neg], dim=0)
    return templates


# Quick test
n = 16
templates = generate_templates(n, tau = (0.5/(n*n)), beta=4.0)

# %%
templates[[0]].sum()
# Out:
# tensor(-0.4414)

# %%
templates.shape
# Out:
# torch.Size([257, 16, 16])

# %%
plot_tensors(templates[:-1].unsqueeze(0), title="Templates")
# Out:
# /var/folders/sx/_3f9ftxx24q3hbz_25d1xrjh0000gn/T/ipykernel_25675/2983223761.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 0.95])

# %%
x0 = read_image("./sample_feature_maps/template_16_16_a.png", mode=ImageReadMode.GRAY) / 255.0
x0
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 x0 = read_image("./sample_feature_maps/template_16_16_a.png", mode=ImageReadMode.GRAY) / 255.0
#       2 x0
#
# File /opt/anaconda3/envs/interpretability/lib/python3.11/site-packages/torchvision/io/image.py:336, in read_image(path, mode, apply_exif_orientation)
#     334 if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#     335     _log_api_usage_once(read_image)
# --> 336 data = read_file(path)
#     337 return decode_image(data, mode, apply_exif_orientation=apply_exif_orientation)
#
# File /opt/anaconda3/envs/interpretability/lib/python3.11/site-packages/torchvision/io/image.py:64, in read_file(path)
#      62 if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#      63     _log_api_usage_once(read_file)
# ---> 64 data = torch.ops.image.read_file(str(path))
#      65 return data
#
# File /opt/anaconda3/envs/interpretability/lib/python3.11/site-packages/torch/_ops.py:1243, in OpOverloadPacket.__call__(self, *args, **kwargs)
#    1241 if self._has_torchbind_op_overload and _must_dispatch_in_python(args, kwargs):
#    1242     return _call_overload_packet_from_python(self, *args, **kwargs)
# -> 1243 return self._op(*args, **kwargs)
#
# RuntimeError: [Errno 2] No such file or directory: './sample_feature_maps/template_16_16_a.png'

# %%
x1 = read_image("./sample_feature_maps/template_16_16_b.png", mode=ImageReadMode.GRAY) / 255.0
x1
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x1 = read_image("./sample_feature_maps/template_16_16_b.png", mode=ImageReadMode.GRAY) / 255.0
#       2 x1
#
# File /opt/anaconda3/envs/interpretability/lib/python3.11/site-packages/torchvision/io/image.py:336, in read_image(path, mode, apply_exif_orientation)
#     334 if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#     335     _log_api_usage_once(read_image)
# --> 336 data = read_file(path)
#     337 return decode_image(data, mode, apply_exif_orientation=apply_exif_orientation)
#
# File /opt/anaconda3/envs/interpretability/lib/python3.11/site-packages/torchvision/io/image.py:64, in read_file(path)
#      62 if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#      63     _log_api_usage_once(read_file)
# ---> 64 data = torch.ops.image.read_file(str(path))
#      65 return data
#
# File /opt/anaconda3/envs/interpretability/lib/python3.11/site-packages/torch/_ops.py:1243, in OpOverloadPacket.__call__(self, *args, **kwargs)
#    1241 if self._has_torchbind_op_overload and _must_dispatch_in_python(args, kwargs):
#    1242     return _call_overload_packet_from_python(self, *args, **kwargs)
# -> 1243 return self._op(*args, **kwargs)
#
# RuntimeError: [Errno 2] No such file or directory: './sample_feature_maps/template_16_16_b.png'

# %%
X = torch.stack([x0, x1], dim=0).squeeze(1)
X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 X = torch.stack([x0, x1], dim=0).squeeze(1)
#       2 X.shape
#
# NameError: name 'x0' is not defined

# %%
plot_tensors(X.unsqueeze(0), title="Feature Maps")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plot_tensors(X.unsqueeze(0), title="Feature Maps")
#
# NameError: name 'X' is not defined

# %%
templates[:-1].shape
# Out:
# torch.Size([256, 16, 16])

# %% [markdown]
# ![image](https://github.com/valentinafeve/interpretability/blob/main/130925/paper.png?raw=1)

# %%
T = torch.randn(1, (n*n+1), n, n)
X = torch.randn(5, 2, n, n)

# %%
def mutual_information(X: torch.Tensor, templates: torch.Tensor, n, device='cpu'):
    atol = 1/(n*n)
    rtol = 1/(n*n)
    X_expanded = X.unsqueeze(2)
    T_expanded = templates.unsqueeze(1)

    XT = torch.mul(X_expanded, T_expanded)
    s_max = XT.max(dim=-1)[0].max(dim=-1)[0]
    s_min = XT.min(dim=-1)[0].min(dim=-1)[0]
    # print(s_max)
    # print(s_min)
    # XT = XT / s_max.unsqueeze(-1).unsqueeze(-1)
    trace = XT.sum(dim=(-1, -2))
    exp = torch.exp(trace)

    # print(exp.shape)
    ZT = exp.sum(dim=1, keepdim=True)

    pXT = exp / ZT # (2 , 257)

    pT = torch.full((1, (n*n+1)), 1/(1+n*n)).to(device) # (1 , 257)
    pX = ((torch.mul(pXT,pT)).sum(dim=1)) # (2)
    sum_pX = pX.sum(dim=1)
    one = torch.tensor(1.0, device=pT.device, dtype=pT.dtype)
    assert torch.allclose(sum_pX, one, rtol=rtol, atol=atol), "sum_x p(x) debe ser 1"


    eps_box = 1e-7
    assert (pXT >= -eps_box).all() and (pXT <= 1+eps_box).all(), "Valores fuera de [0,1] en p(x|T)"
    assert (pX  >= -eps_box).all() and (pX  <= 1+eps_box).all(), "Valores fuera de [0,1] en p(x)"
    eps = 1e-12
    ratio = pXT.clamp_min(eps) / pX.unsqueeze(1).clamp_min(eps)
    MI = ((pT) * (pXT * torch.log(ratio)).sum(dim=-2)).sum(dim=-1)
    return MI

# %%
MI = mutual_information(X, T, X.shape[-1])
MI
# Out:
# tensor([5.5022, 5.4913, 5.5069, 5.4887, 5.4795])

# %% [markdown]
# ## Preparación de los datos

# %%
DESIRED_SHAPE = 64
transform = transforms.Compose(
    [  
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
        # transforms.Normalize((0.5), (0.5)),
        transforms.Resize((DESIRED_SHAPE, DESIRED_SHAPE)),
        transforms.CenterCrop((DESIRED_SHAPE, DESIRED_SHAPE)),
        # transforms.ColorJitter(brightness=1.8),
    ]    
    )

batch_size = 5

dataset = load_dataset("Hemg/Melanoma-Cancer-Image-Dataset", split="train")
trainset, testset = dataset.train_test_split(test_size=0.1, seed=42).values()

# %%
trainset = trainset.with_format("torch")
testset  = testset.with_format("torch")

# %%
trainset[0]
# Out:
# {'image': tensor([[[150, 150, 149,  ..., 149, 131, 134],
#           [151, 151, 151,  ..., 127, 127, 152],
#           [152, 151, 151,  ..., 121, 137, 123],
#           ...,
#           [147, 147, 148,  ..., 136, 136, 137],
#           [146, 146, 146,  ..., 135, 135, 135],
#           [145, 145, 146,  ..., 136, 136, 136]],
#
#          [[119, 119, 118,  ..., 122, 104, 107],
#           [120, 120, 120,  ..., 100, 100, 125],
#           [121, 120, 120,  ...,  94, 110,  96],
#           ...,
#           [114, 114, 115,  ..., 105, 105, 106],
#           [113, 113, 113,  ..., 104, 104, 104],
#           [112, 112, 113,  ..., 105, 105, 105]],
#
#          [[124, 124, 123,  ..., 127, 109, 112],
#           [125, 125, 125,  ..., 105, 105, 130],
#           [126, 125, 125,  ...,  99, 115, 101],
#           ...,
#           [121, 121, 122,  ..., 111, 111, 112],
#           [120, 120, 120,  ..., 110, 110, 110],
#           [119, 119, 120,  ..., 111, 111, 111]]], dtype=torch.uint8),
#  'label': tensor(1)}

# %%
trainset = trainset.with_transform(lambda examples: {'image': [transform(img) for img in examples['image']], 'label': examples['label']})

# %%
testset = testset.with_transform(lambda examples: {'image': [transform(img) for img in examples['image']], 'label': examples['label']})

# %%
testset
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 1188
# })

# %%
trainset[0]['image']
# Out:
# tensor([[[ 0.1754,  0.1865,  0.1779,  ...,  0.1559,  0.1148,  0.0192],
#          [ 0.1543,  0.1750,  0.1776,  ...,  0.1677,  0.0998, -0.2025],
#          [ 0.1896,  0.1844,  0.1747,  ...,  0.1802,  0.0843, -0.0538],
#          ...,
#          [ 0.1505,  0.1734,  0.1791,  ...,  0.1200,  0.1369,  0.1283],
#          [ 0.1644,  0.1811,  0.1811,  ...,  0.0984,  0.0918,  0.0854],
#          [ 0.1534,  0.1701,  0.1812,  ...,  0.0889,  0.0859,  0.0703]],
#
#         [[-0.0678, -0.0567, -0.0652,  ..., -0.0857, -0.1097, -0.1936],
#          [-0.0889, -0.0681, -0.0655,  ..., -0.0738, -0.1248, -0.4153],
#          [-0.0535, -0.0587, -0.0684,  ..., -0.0613, -0.1403, -0.2667],
#          ...,
#          [-0.1083, -0.0854, -0.0798,  ..., -0.1232, -0.1063, -0.1149],
#          [-0.0944, -0.0777, -0.0777,  ..., -0.1447, -0.1513, -0.1578],
#          [-0.1054, -0.0887, -0.0776,  ..., -0.1542, -0.1572, -0.1729]],
#
#         [[-0.0286, -0.0174, -0.0260,  ..., -0.0394, -0.0703, -0.1544],
#          [-0.0496, -0.0289, -0.0263,  ..., -0.0276, -0.0854, -0.3761],
#          [-0.0143, -0.0195, -0.0292,  ..., -0.0151, -0.1009, -0.2275],
#          ...,
#          [-0.0534, -0.0305, -0.0249,  ..., -0.0761, -0.0592, -0.0678],
#          [-0.0395, -0.0228, -0.0228,  ..., -0.0977, -0.1042, -0.1107],
#          [-0.0505, -0.0338, -0.0227,  ..., -0.1071, -0.1102, -0.1258]]])

# %%
classes = trainset.features['label'].names
classes
# Out:
# ['Benign', 'Malignant']

# %%
print("Dataset loaded with {} classes of values {}".format(len(classes), ', '.join(classes)))
# Dataset loaded with 2 classes of values Benign, Malignant
# Out:
# Dataset loaded with 2 classes of values Benign, Malignant

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=0)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=0)

# %%
cont = 0
for batch in trainloader:
    print(batch)
    print(batch['image'].shape)
    show(torchvision.utils.make_grid(batch['image']))
    print(batch['label'])
    cont+=1
    if cont==5:
        break
# Out:
# {'image': tensor([[[[ 5.0997e-02,  1.5767e-01,  2.6184e-01,  ...,  4.1812e-01,
#             3.8043e-01,  2.2163e-01],
#           [ 1.1605e-01,  2.1657e-01,  3.0667e-01,  ...,  5.2363e-01,
#             4.6877e-01,  2.9509e-01],
#           [ 2.3308e-01,  2.7947e-01,  3.5229e-01,  ...,  5.8076e-01,
#             5.1283e-01,  3.1682e-01],
#           ...,
#           [ 2.6528e-01,  3.0907e-01,  4.1959e-01,  ...,  5.8251e-01,
#             5.1117e-01,  3.4972e-01],
#           [ 2.4965e-01,  2.8348e-01,  3.6404e-01,  ...,  5.6000e-01,
#             4.9067e-01,  3.5692e-01],
#           [ 2.2766e-01,  2.5395e-01,  2.7361e-01,  ...,  2.8501e-01,
#             2.2405e-01,  1.1951e-01]],
#
#          [[-1.5921e-01, -9.4592e-02, -2.5061e-02,  ...,  1.0473e-01,
#             1.4831e-01,  7.3382e-02],
#           [-1.2564e-01, -6.5582e-02, -5.8652e-03,  ...,  1.2027e-01,
#             1.4556e-01,  5.0147e-02],
#           [-5.8124e-02, -5.1500e-02, -5.5908e-03,  ...,  1.9188e-01,
#             2.0069e-01,  8.0793e-02],
#           ...,
#           [-1.4940e-02, -1.6929e-02,  6.8685e-02,  ...,  2.2433e-01,
#             1.9308e-01,  7.6509e-02],
#           [-1.1061e-02, -1.6789e-02,  3.3560e-02,  ...,  2.0731e-01,
#             1.5588e-01,  5.9974e-02],
#           [ 2.7933e-03, -1.2684e-02, -1.8249e-02,  ...,  3.0034e-02,
#            -1.8543e-02, -9.3997e-02]],
#
#          [[-4.0313e-01, -3.1789e-01, -2.2970e-01,  ..., -1.3092e-01,
#            -1.4135e-01, -1.1559e-01],
#           [-4.9020e-01, -4.2060e-01, -3.5533e-01,  ..., -2.2731e-01,
#            -2.4656e-01, -2.3518e-01],
#           [-3.9862e-01, -3.9239e-01, -3.5840e-01,  ..., -1.6452e-01,
#            -1.7751e-01, -1.8091e-01],
#           ...,
#           [-3.6858e-01, -3.6593e-01, -2.8728e-01,  ..., -1.5720e-01,
#            -1.4645e-01, -2.1613e-01],
#           [-3.3160e-01, -3.3305e-01, -2.8620e-01,  ..., -1.6040e-01,
#            -1.5805e-01, -2.0734e-01],
#           [-2.7559e-01, -2.8960e-01, -3.0074e-01,  ..., -2.2293e-01,
#            -2.1271e-01, -2.3566e-01]]],
#
#
#         [[[ 2.0866e-01,  3.0310e-01,  3.3493e-01,  ...,  2.9250e-01,
#            -3.2041e-02, -5.1518e-01],
#           [ 2.6292e-01,  3.2456e-01,  3.5359e-01,  ...,  3.0093e-01,
#             1.1468e-01, -4.9859e-01],
#           [ 2.4887e-01,  2.9173e-01,  3.2057e-01,  ...,  3.2490e-01,
#             2.2758e-01, -1.6576e-01],
#           ...,
#            -4.8699e-01, -5.5691e-01],
#           [-1.5286e-01,  1.6965e-02, -3.9832e-02,  ..., -5.6560e-01,
#            -5.5760e-01, -6.1401e-01]]]]), 'label': tensor([0, 1, 1, 1, 1])}
# torch.Size([5, 3, 64, 64])
# tensor([0, 1, 1, 1, 1])
# {'image': tensor([[[[ 0.4775,  0.5002,  0.5114,  ...,  0.3013,  0.3137,  0.2750],
#           [ 0.4819,  0.4999,  0.4910,  ...,  0.2825,  0.3004,  0.2737],
#           [ 0.4830,  0.4893,  0.5083,  ...,  0.2781,  0.2794,  0.2887],
#           ...,
#           [ 0.1642,  0.1723,  0.2160,  ...,  0.4784,  0.4315,  0.4242],
#           [ 0.1701,  0.1521,  0.1687,  ...,  0.4544,  0.4310,  0.4209],
#           [ 0.1441,  0.1543,  0.1827,  ...,  0.4023,  0.4016,  0.4039]],
#
#          [[ 0.1131,  0.1620,  0.1853,  ...,  0.0033,  0.0156, -0.0231],
#           [ 0.1063,  0.1485,  0.1510,  ..., -0.0154,  0.0026, -0.0241],
#           [ 0.0927,  0.1214,  0.1504,  ..., -0.0145, -0.0132, -0.0039],
#           ...,
#           [-0.2478, -0.2378, -0.1848,  ...,  0.1701,  0.1497,  0.1264],
#           [-0.2659, -0.2421, -0.2035,  ...,  0.1329,  0.1328,  0.1113],
#           [-0.3273, -0.2575, -0.1967,  ...,  0.0745,  0.0996,  0.0805]],
#
#          [[-0.0032,  0.0838,  0.1326,  ..., -0.0841, -0.0717, -0.1104],
#           [-0.0050,  0.0743,  0.1012,  ..., -0.1146, -0.0967, -0.1234],
#           [-0.0136,  0.0527,  0.1067,  ..., -0.1327, -0.1315, -0.1222],
#           ...,
#           [-0.2672, -0.2582, -0.2085,  ...,  0.1411,  0.0928,  0.0659],
#           [-0.2772, -0.2684, -0.2367,  ...,  0.0902,  0.0668,  0.0436],
#           [-0.3264, -0.2775, -0.2281,  ...,  0.0250,  0.0285,  0.0072]]],
#
#
#         [[[ 0.3174,  0.3663,  0.4137,  ...,  0.4230,  0.4143,  0.4329],
#           [ 0.3627,  0.4036,  0.4424,  ...,  0.4172,  0.4398,  0.4320],
#           [ 0.3914,  0.4013,  0.4252,  ...,  0.4325,  0.4186,  0.4034],
#           ...,
#           [ 0.3229,  0.3680,  0.3976,  ...,  0.5297,  0.4973,  0.4814],
#           [ 0.2938,  0.3356,  0.3511,  ...,  0.5033,  0.4858,  0.4766],
#           [ 0.2523,  0.3098,  0.3380,  ...,  0.4360,  0.4209,  0.4307]],
#
#          [[-0.0606, -0.0236,  0.0048,  ..., -0.0369, -0.0708, -0.0695],
#           [-0.0416, -0.0083,  0.0238,  ..., -0.0421, -0.0349, -0.0531],
#           [-0.0518, -0.0399, -0.0037,  ..., -0.0301, -0.0407, -0.0566],
#           ...,
#           [-0.1297, -0.0800, -0.0411,  ...,  0.1042,  0.0849,  0.0766],
#           [-0.1265, -0.0908, -0.0901,  ...,  0.0669,  0.0585,  0.0555],
#           [-0.1495, -0.1061, -0.1053,  ..., -0.0103, -0.0158,  0.0059]],
#
#          [[-0.2001, -0.1792, -0.1761,  ..., -0.2076, -0.2465, -0.2445],
#           [-0.1824, -0.1680, -0.1653,  ..., -0.2287, -0.2184, -0.2288],
#           [-0.1987, -0.2020, -0.2044,  ..., -0.2331, -0.2273, -0.2273],
#           ...,
#           [-0.2304, -0.1922, -0.1754,  ..., -0.1098, -0.0997, -0.0931],
#           [-0.2575, -0.2293, -0.2406,  ..., -0.1579, -0.1401, -0.1229],
#           [-0.2978, -0.2594, -0.2619,  ..., -0.2394, -0.2157, -0.1821]]],
#
#
#         [[[ 0.2615,  0.2962,  0.3439,  ...,  0.4819,  0.4638,  0.4652],
#           [ 0.3056,  0.3189,  0.3358,  ...,  0.4927,  0.5049,  0.4968],
#           [ 0.3215,  0.3338,  0.3466,  ...,  0.5456,  0.5354,  0.4858],
#           ...,
#           [ 0.4646,  0.4594,  0.4770,  ...,  0.5739,  0.5603,  0.5288],
#           [ 0.4444,  0.4331,  0.4440,  ...,  0.5600,  0.5531,  0.5195],
#           [ 0.4436,  0.4548,  0.4642,  ...,  0.5789,  0.5536,  0.5128]],
#
#          [[ 0.1516,  0.1864,  0.2341,  ...,  0.4377,  0.4172,  0.4149],
#           [ 0.1958,  0.2091,  0.2260,  ...,  0.4727,  0.5131,  0.5228],
#           [ 0.2117,  0.2240,  0.2368,  ...,  0.5337,  0.5652,  0.5414],
#           ...,
#           [ 0.3627,  0.3575,  0.3751,  ...,  0.5817,  0.5681,  0.5367],
#           [ 0.3424,  0.3311,  0.3421,  ...,  0.5679,  0.5610,  0.5273],
#           [ 0.3417,  0.3528,  0.3622,  ...,  0.5867,  0.5614,  0.5207]],
#
#          [[ 0.2850,  0.3197,  0.3674,  ...,  0.4883,  0.4689,  0.4679],
#           [ 0.3292,  0.3424,  0.3593,  ...,  0.5222,  0.5531,  0.5563],
#           [ 0.3450,  0.3573,  0.3701,  ...,  0.5945,  0.6124,  0.5800],
#           ...,
#           [ 0.5195,  0.5143,  0.5319,  ...,  0.6131,  0.5995,  0.5680],
#           [ 0.4993,  0.4880,  0.4989,  ...,  0.5992,  0.5923,  0.5587],
#           [ 0.4985,  0.5097,  0.5191,  ...,  0.6181,  0.5928,  0.5521]]],
#
#
#         [[[ 0.6101,  0.6137,  0.6210,  ...,  0.6433,  0.6395,  0.6314],
#           [ 0.5665,  0.5466,  0.5627,  ...,  0.6341,  0.6312,  0.6231],
#           [ 0.5895,  0.5556,  0.5264,  ...,  0.6210,  0.6188,  0.6096],
#           ...,
#           [-0.1716, -0.2061, -0.2471,  ...,  0.2420,  0.1870,  0.1491],
#           [-0.0940, -0.1496, -0.2023,  ...,  0.4338,  0.4018,  0.3795],
#           [-0.0389, -0.1148, -0.1765,  ...,  0.5501,  0.5581,  0.5570]],
#
#          [[ 0.5249,  0.5285,  0.5358,  ...,  0.6448,  0.6387,  0.6260],
#           [ 0.4929,  0.4729,  0.4890,  ...,  0.6344,  0.6312,  0.6223],
#           [ 0.5244,  0.4905,  0.4613,  ...,  0.6210,  0.6191,  0.6111],
#           ...,
#           [-0.2807, -0.3067, -0.3356,  ...,  0.1234,  0.0681,  0.0310],
#           [-0.2350, -0.2795, -0.3192,  ...,  0.3588,  0.3266,  0.3048],
#           [-0.1946, -0.2651, -0.3073,  ...,  0.5021,  0.5102,  0.5090]],
#
#          [[ 0.4784,  0.4820,  0.4893,  ...,  0.7082,  0.7288,  0.7308],
#           [ 0.4524,  0.4324,  0.4485,  ...,  0.7012,  0.7128,  0.7124],
#           [ 0.4976,  0.4637,  0.4345,  ...,  0.6928,  0.6858,  0.6745],
#           ...,
#           [-0.2437, -0.2588, -0.2768,  ...,  0.0120, -0.0430, -0.0810],
#           [-0.2187, -0.2578, -0.2829,  ...,  0.2818,  0.2498,  0.2275],
#           [-0.1903, -0.2531, -0.2894,  ...,  0.4469,  0.4549,  0.4537]]],
#
#
#         [[[-0.4393, -0.1758, -0.0165,  ...,  0.3796,  0.3062,  0.2130],
#           [-0.3599, -0.1203,  0.0400,  ...,  0.4222,  0.3535,  0.2777],
#           [-0.2077, -0.0407,  0.1018,  ...,  0.4380,  0.4099,  0.3512],
#           ...,
#           [-0.1102, -0.0347,  0.0602,  ...,  0.4423,  0.4275,  0.3838],
#           [-0.1547, -0.0878,  0.0188,  ...,  0.4570,  0.4225,  0.3508],
#           [-0.1869, -0.1253, -0.0237,  ...,  0.4546,  0.3974,  0.3376]],
#
#          [[-0.6210, -0.3986, -0.2626,  ...,  0.2050,  0.1089, -0.0283],
#           [-0.5606, -0.3495, -0.2033,  ...,  0.2476,  0.1561,  0.0363],
#           [-0.4318, -0.2806, -0.1431,  ...,  0.2633,  0.2125,  0.1099],
#           ...,
#           [-0.3830, -0.2869, -0.1709,  ...,  0.2060,  0.2165,  0.1859],
#           [-0.4252, -0.3378, -0.2120,  ...,  0.2207,  0.2116,  0.1529],
#           [-0.4552, -0.3751, -0.2545,  ...,  0.2183,  0.1864,  0.1397]],
#
#          [[-0.6133, -0.3853, -0.2181,  ...,  0.3566,  0.2540,  0.1175],
#           [-0.5530, -0.3317, -0.1473,  ...,  0.3992,  0.3013,  0.1821],
#           [-0.4251, -0.2582, -0.0684,  ...,  0.4149,  0.3577,  0.2556],
#           ...,
#           [-0.2815, -0.1640, -0.0099,  ...,  0.4415,  0.4275,  0.3600],
#           [-0.3397, -0.2291, -0.0631,  ...,  0.4562,  0.4225,  0.3269],
#           [-0.3845, -0.2771, -0.1133,  ...,  0.4538,  0.3974,  0.3137]]]]), 'label': tensor([0, 0, 1, 1, 0])}
# torch.Size([5, 3, 64, 64])
# tensor([0, 0, 1, 1, 0])
# {'image': tensor([[[[ 7.5826e-01,  7.6704e-01,  7.5673e-01,  ...,  7.3917e-01,
#             7.5135e-01,  7.5038e-01],
#           [ 7.5661e-01,  7.5363e-01,  7.4762e-01,  ...,  7.3174e-01,
#             7.5170e-01,  7.6321e-01],
#           [ 7.5187e-01,  7.4879e-01,  7.3803e-01,  ...,  7.1551e-01,
 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           ...,
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00]],
#
#          [[ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           ...,
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00]],
#
#          [[ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           ...,
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00],
#           [ 1.0000e+00,  1.0000e+00,  1.0000e+00,  ...,  1.0000e+00,
#             1.0000e+00,  1.0000e+00]]]]), 'label': tensor([1, 0, 0, 0, 1])}
# torch.Size([5, 3, 64, 64])
# tensor([1, 0, 0, 0, 1])
# {'image': tensor([[[[ 0.3620,  0.3884,  0.4506,  ...,  0.4817,  0.4146,  0.3531],
#           [ 0.3744,  0.4141,  0.4571,  ...,  0.4898,  0.4223,  0.3761],
#           [ 0.3796,  0.4242,  0.4587,  ...,  0.4964,  0.4311,  0.3741],
#           ...,
#           [ 0.3059,  0.3327,  0.4012,  ...,  0.3628,  0.3101,  0.2683],
#           [ 0.2900,  0.3308,  0.3893,  ...,  0.3310,  0.2898,  0.2561],
#           [ 0.2936,  0.3202,  0.3776,  ...,  0.3370,  0.2799,  0.2311]],
#
#          [[-0.0537, -0.0325,  0.0087,  ...,  0.0532,  0.0072, -0.0469],
#           [-0.0413, -0.0067,  0.0152,  ...,  0.0613,  0.0149, -0.0239],
#           [-0.0361,  0.0033,  0.0167,  ...,  0.0679,  0.0237, -0.0259],
#           ...,
#           [-0.0903, -0.0668, -0.0194,  ..., -0.0009, -0.0398, -0.0688],
#           [-0.1061, -0.0688, -0.0313,  ..., -0.0327, -0.0601, -0.0810],
#           [-0.1026, -0.0794, -0.0431,  ..., -0.0266, -0.0700, -0.1059]],
#
#          [[-0.3047, -0.2809, -0.2292,  ..., -0.1791, -0.2149, -0.2597],
#           [-0.2923, -0.2551, -0.2227,  ..., -0.1710, -0.2073, -0.2367],
#           [-0.2871, -0.2451, -0.2211,  ..., -0.1644, -0.1985, -0.2387],
#           ...,
#           [-0.3411, -0.3280, -0.2891,  ..., -0.2834, -0.3276, -0.3630],
#           [-0.3569, -0.3300, -0.3011,  ..., -0.3152, -0.3479, -0.3752],
#           [-0.3534, -0.3406, -0.3128,  ..., -0.3092, -0.3578, -0.4002]]],
#
#
#         [[[ 0.7768,  0.7857,  0.7735,  ...,  0.7919,  0.7749,  0.7618],
#           [ 0.7837,  0.7816,  0.7702,  ...,  0.8134,  0.7867,  0.7658],
#           [ 0.7943,  0.7857,  0.7829,  ...,  0.8241,  0.7906,  0.7721],
#           ...,
#           [ 0.6658,  0.6704,  0.6785,  ...,  0.6152,  0.6169,  0.5973],
#           [ 0.6531,  0.6564,  0.6686,  ...,  0.6035,  0.6093,  0.5978],
#           [ 0.6496,  0.6664,  0.6814,  ...,  0.6039,  0.5949,  0.5895]],
#
#          [[ 0.2042,  0.2107,  0.1933,  ...,  0.2194,  0.2023,  0.1893],
#           [ 0.2112,  0.2067,  0.1900,  ...,  0.2409,  0.2141,  0.1933],
#           [ 0.2217,  0.2108,  0.2027,  ...,  0.2515,  0.2180,  0.1996],
#           ...,
#           [ 0.1874,  0.1919,  0.2001,  ...,  0.0975,  0.0993,  0.0797],
#           [ 0.1747,  0.1780,  0.1902,  ...,  0.0859,  0.0917,  0.0801],
#           [ 0.1711,  0.1880,  0.2030,  ...,  0.0863,  0.0772,  0.0719]],
#
#          [[ 0.3571,  0.3748,  0.3764,  ...,  0.3684,  0.3513,  0.3383],
#           [ 0.3640,  0.3708,  0.3731,  ...,  0.3899,  0.3631,  0.3423],
#           [ 0.3746,  0.3748,  0.3858,  ...,  0.4005,  0.3671,  0.3486],
#           ...,
#           [ 0.2501,  0.2547,  0.2628,  ...,  0.1760,  0.1777,  0.1581],
#           [ 0.2374,  0.2408,  0.2530,  ...,  0.1643,  0.1701,  0.1586],
#           [ 0.2339,  0.2507,  0.2657,  ...,  0.1647,  0.1557,  0.1503]]],
#
#
#         [[[ 0.2143,  0.2713,  0.3164,  ...,  0.4179,  0.3297,  0.2928],
#           [ 0.2238,  0.2923,  0.3405,  ...,  0.4393,  0.3504,  0.3095],
#           [ 0.2332,  0.2942,  0.3345,  ...,  0.4457,  0.3832,  0.3031],
#           ...,
#           [ 0.1061,  0.1762,  0.2308,  ...,  0.4062,  0.3483,  0.3000],
#           [ 0.0554,  0.1503,  0.2175,  ...,  0.3801,  0.3235,  0.2811],
#           [ 0.0710,  0.1368,  0.1930,  ...,  0.3527,  0.3148,  0.2716]],
#
#          [[-0.1542, -0.1124, -0.0848,  ...,  0.0229, -0.0515, -0.0756],
#           [-0.1446, -0.0913, -0.0606,  ...,  0.0443, -0.0309, -0.0589],
#           [-0.1353, -0.0894, -0.0666,  ...,  0.0506,  0.0019, -0.0654],
#           ...,
#           [-0.1857, -0.1381, -0.1162,  ...,  0.0776,  0.0381,  0.0045],
#           [-0.2365, -0.1639, -0.1295,  ...,  0.0705,  0.0337,  0.0012],
#           [-0.2209, -0.1774, -0.1540,  ...,  0.0563,  0.0349, -0.0009]],
#
#          [[-0.3307, -0.2825, -0.2496,  ..., -0.1559, -0.2319, -0.2601],
#           [-0.3212, -0.2615, -0.2255,  ..., -0.1345, -0.2113, -0.2433],
#           [-0.3118, -0.2596, -0.2315,  ..., -0.1282, -0.1785, -0.2498],
#           ...,
#           [-0.3891, -0.3332, -0.2991,  ..., -0.1204, -0.1665, -0.2056],
#           [-0.4398, -0.3590, -0.3124,  ..., -0.1343, -0.1788, -0.2157],
#           [-0.4242, -0.3725, -0.3370,  ..., -0.1534, -0.1821, -0.2205]]],
#
#
#         [[[ 0.5129,  0.5283,  0.5571,  ...,  0.5399,  0.5222,  0.4918],
#           [ 0.5238,  0.5463,  0.5836,  ...,  0.5297,  0.5247,  0.5003],
#           [ 0.5393,  0.5544,  0.5700,  ...,  0.5028,  0.5268,  0.5078],
#           ...,
#           [ 0.4039,  0.4474,  0.4758,  ...,  0.5471,  0.5131,  0.4673],
#           [ 0.3813,  0.4343,  0.4573,  ...,  0.5299,  0.5056,  0.4533],
#           [ 0.3758,  0.4291,  0.4529,  ...,  0.5109,  0.4821,  0.4335]],
#
#          [[ 0.1992,  0.2119,  0.2248,  ...,  0.2105,  0.1912,  0.1551],
#           [ 0.2101,  0.2298,  0.2513,  ...,  0.2003,  0.1937,  0.1636],
#           [ 0.2256,  0.2380,  0.2377,  ...,  0.1734,  0.1958,  0.1711],
#           ...,
#           [ 0.1078,  0.1546,  0.1858,  ...,  0.2334,  0.1994,  0.1535],
#           [ 0.0833,  0.1369,  0.1644,  ...,  0.2161,  0.1919,  0.1396],
#           [ 0.0777,  0.1311,  0.1568,  ...,  0.1972,  0.1684,  0.1198]],
#
#          [[ 0.2697,  0.2799,  0.2823,  ...,  0.2294,  0.2271,  0.2083],
#           [ 0.2807,  0.2979,  0.3088,  ...,  0.2191,  0.2296,  0.2169],
#           [ 0.2961,  0.3060,  0.2952,  ...,  0.1923,  0.2316,  0.2243],
#           ...,
#           [ 0.1911,  0.2248,  0.2434,  ...,  0.2988,  0.2807,  0.2398],
#           [ 0.1843,  0.2277,  0.2347,  ...,  0.2816,  0.2732,  0.2259],
#           [ 0.1905,  0.2322,  0.2400,  ...,  0.2626,  0.2497,  0.2060]]],
#
#
#         [[[ 0.1801,  0.2738,  0.2969,  ...,  0.4828,  0.4370,  0.3721],
#           [ 0.2139,  0.2610,  0.2983,  ...,  0.4716,  0.4297,  0.3532],
#           [ 0.2047,  0.2798,  0.3400,  ...,  0.4583,  0.4091,  0.3582],
#           ...,
#           [-0.1557, -0.0601,  0.0082,  ...,  0.4083,  0.3638,  0.3262],
#           [-0.1659, -0.0723,  0.0059,  ...,  0.4193,  0.3441,  0.3142],
#           [-0.1908, -0.0642, -0.0052,  ...,  0.3786,  0.2561,  0.2790]],
#
#          [[ 0.0227,  0.0986,  0.1308,  ...,  0.2763,  0.2197,  0.1524],
#           [ 0.0690,  0.0941,  0.1311,  ...,  0.2651,  0.2091,  0.1310],
#           [ 0.0827,  0.1251,  0.1706,  ...,  0.2554,  0.1867,  0.1309],
#           ...,
#           [-0.2735, -0.2320, -0.2021,  ...,  0.3849,  0.3294,  0.2650],
#           [-0.2837, -0.2442, -0.2044,  ...,  0.4108,  0.3270,  0.2694],
#           [-0.3087, -0.2361, -0.2155,  ...,  0.3826,  0.2497,  0.2417]],
#
#          [[-0.0655,  0.0144,  0.0448,  ...,  0.1409,  0.0601, -0.0176],
#           [-0.0236,  0.0078,  0.0446,  ...,  0.1275,  0.0605, -0.0262],
#           [-0.0178,  0.0355,  0.0842,  ...,  0.1094,  0.0544,  0.0032],
#           ...,
#           [-0.4408, -0.4210, -0.4041,  ...,  0.2422,  0.1657,  0.0683],
#           [-0.4510, -0.4333, -0.4064,  ...,  0.2624,  0.1575,  0.0679],
#           [-0.4759, -0.4251, -0.4175,  ...,  0.2317,  0.0768,  0.0373]]]]), 'label': tensor([0, 0, 0, 0, 1])}
# torch.Size([5, 3, 64, 64])
# tensor([0, 0, 0, 0, 1])
# {'image': tensor([[[[-0.2807, -0.1595,  0.0104,  ...,  0.2661,  0.2124,  0.1061],
#           [-0.2167, -0.0850,  0.0571,  ...,  0.3105,  0.2400,  0.1209],
#           [-0.1430,  0.0026,  0.1030,  ...,  0.3373,  0.2529,  0.1388],
#           ...,
#           [-0.1096, -0.0231,  0.1106,  ...,  0.3363,  0.2915,  0.1983],
#           [-0.1967, -0.0521,  0.0593,  ...,  0.3445,  0.3022,  0.1897],
#           [-0.2752, -0.1010,  0.0123,  ...,  0.3575,  0.3135,  0.1979]],
#
#          [[-0.6242, -0.4857, -0.3025,  ..., -0.0398, -0.0916, -0.1924],
#           [-0.5601, -0.4112, -0.2558,  ...,  0.0019, -0.0655, -0.1822],
#           [-0.4865, -0.3236, -0.2099,  ...,  0.0136, -0.0669, -0.1801],
#           ...,
#           [-0.4861, -0.3967, -0.2435,  ..., -0.0037, -0.0274, -0.1154],
#           [-0.5732, -0.4257, -0.2947,  ...,  0.0045, -0.0167, -0.1240],
#           [-0.6517, -0.4746, -0.3418,  ...,  0.0175, -0.0053, -0.1158]],
#
#          [[-0.6482, -0.5107, -0.3169,  ..., -0.0177, -0.0849, -0.1993],
#           [-0.5842, -0.4361, -0.2703,  ...,  0.0127, -0.0670, -0.1921],
#           [-0.5105, -0.3486, -0.2243,  ...,  0.0194, -0.0777, -0.2024],
#           ...,
#           [-0.5948, -0.4890, -0.3120,  ...,  0.0040, -0.0250, -0.1154],
#           [-0.6819, -0.5181, -0.3632,  ...,  0.0122, -0.0143, -0.1240],
#           [-0.7604, -0.5669, -0.4103,  ...,  0.0252, -0.0029, -0.1158]]],
#
#
#         [[[-0.7193, -0.4327, -0.1374,  ..., -0.6845, -0.9191, -0.9921],
#           [-0.4713, -0.1832,  0.0498,  ..., -0.3601, -0.7169, -0.9358],
#           [-0.2292, -0.0116,  0.1674,  ..., -0.0323, -0.3808, -0.6927],
#           ...,
#           [ 0.6320,  0.7236,  0.7913,  ...,  0.2912,  0.1753,  0.0171],
#           [ 0.5262,  0.6381,  0.7403,  ...,  0.1821, -0.0012, -0.2210],
#           [ 0.4136,  0.5391,  0.6600,  ...,  0.0352, -0.1967, -0.4671]],
#
#          [[-0.7924, -0.5313, -0.2886,  ..., -0.7820, -0.9374, -0.9671],
#           [-0.5658, -0.3087, -0.1235,  ..., -0.4975, -0.7736, -0.9415],
#           [-0.3517, -0.1674, -0.0405,  ..., -0.2673, -0.5355, -0.7980],
#           ...,
#           [ 0.5303,  0.6220,  0.6897,  ...,  0.0693, -0.0122, -0.1538],
#           [ 0.3981,  0.5100,  0.6123,  ..., -0.0212, -0.1678, -0.3660],
#           [ 0.2802,  0.4058,  0.5267,  ..., -0.1551, -0.3484, -0.5958]],
#
#          [[-0.7483, -0.5148, -0.2475,  ..., -0.7664, -0.9484, -0.9928],
#           [-0.5270, -0.2766, -0.0674,  ..., -0.4681, -0.7717, -0.9562],
#           [-0.3121, -0.1130,  0.0303,  ..., -0.2050, -0.5006, -0.7797],
#           ...,
#           [ 0.5643,  0.6559,  0.7236,  ...,  0.1825,  0.0943, -0.0555],
#           [ 0.4426,  0.5545,  0.6568,  ...,  0.0754, -0.0967, -0.3127],
#           [ 0.3273,  0.4529,  0.5737,  ..., -0.0744, -0.3066, -0.5761]]],
#
#
#         [[[-0.8175, -0.5847, -0.3168,  ..., -0.4695, -0.7404, -0.9153],
#           [-0.5802, -0.3192, -0.0851,  ..., -0.2346, -0.5037, -0.7556],
#           [-0.3026, -0.0828,  0.0992,  ..., -0.0189, -0.2566, -0.5056],
#           ...,
#           [-0.5513, -0.3142, -0.0848,  ..., -0.2642, -0.5252, -0.7458],
#           [-0.7816, -0.5676, -0.3199,  ..., -0.5249, -0.7586, -0.9067],
#           [-0.8879, -0.7690, -0.5683,  ..., -0.7557, -0.9075, -0.9557]],
#
#          [[-0.8097, -0.5792, -0.3166,  ..., -0.4460, -0.7168, -0.8918],
#           [-0.5725, -0.3138, -0.0848,  ..., -0.2060, -0.4750, -0.7270],
#           [-0.2998, -0.0768,  0.1047,  ...,  0.0309, -0.2069, -0.4558],
#           ...,
#           [-0.5333, -0.3066, -0.0818,  ..., -0.2564, -0.5173, -0.7380],
#           [-0.7835, -0.5665, -0.3086,  ..., -0.5171, -0.7508, -0.8989],
#           [-0.9056, -0.7694, -0.5466,  ..., -0.7478, -0.8996, -0.9479]],
#
#          [[-0.7742, -0.5325, -0.2405,  ..., -0.4057, -0.6765, -0.8515],
#           [-0.5337, -0.2672, -0.0148,  ..., -0.1563, -0.4254, -0.6774],
#           [-0.2454, -0.0321,  0.1500,  ...,  0.0890, -0.1488, -0.3977],
#           ...,
#           [-0.4760, -0.2488, -0.0284,  ..., -0.2250, -0.4859, -0.7066],
#           [-0.7574, -0.5331, -0.2707,  ..., -0.4857, -0.7194, -0.8675],
#           [-0.9013, -0.7559, -0.5173,  ..., -0.7165, -0.8682, -0.9165]]],
#
#
#         [[[ 0.8320,  0.8573,  0.8527,  ...,  0.8488,  0.8515,  0.8557],
#           [ 0.8314,  0.8455,  0.8591,  ...,  0.8535,  0.8555,  0.8483],
#           [ 0.8266,  0.8364,  0.8527,  ...,  0.8522,  0.8520,  0.8355],
#           ...,
#           [ 0.7007,  0.6982,  0.7042,  ...,  0.7360,  0.7188,  0.7134],
#           [ 0.7052,  0.7112,  0.6983,  ...,  0.7351,  0.7315,  0.7241],
#           [ 0.6968,  0.7033,  0.7019,  ...,  0.7290,  0.7243,  0.7126]],
#
#          [[ 0.0632,  0.0885,  0.0839,  ...,  0.1586,  0.1613,  0.1655],
#           [ 0.0754,  0.0895,  0.1031,  ...,  0.1633,  0.1653,  0.1581],
#           [ 0.0843,  0.0941,  0.1104,  ...,  0.1620,  0.1618,  0.1453],
#           ...,
#           [ 0.1281,  0.1209,  0.1147,  ...,  0.1529,  0.1547,  0.1565],
#           [ 0.1326,  0.1338,  0.1088,  ...,  0.1520,  0.1674,  0.1672],
#           [ 0.1243,  0.1260,  0.1124,  ...,  0.1459,  0.1602,  0.1557]],
#
#          [[ 0.2168,  0.2421,  0.2375,  ...,  0.2841,  0.2868,  0.2910],
#           [ 0.2310,  0.2451,  0.2587,  ...,  0.2888,  0.2908,  0.2836],
#           [ 0.2505,  0.2603,  0.2766,  ...,  0.2875,  0.2873,  0.2708],
#           ...,
#           [ 0.1830,  0.1710,  0.1526,  ...,  0.1465,  0.1415,  0.1408],
#           [ 0.1875,  0.1839,  0.1467,  ...,  0.1456,  0.1541,  0.1515],
#           [ 0.1792,  0.1761,  0.1503,  ...,  0.1395,  0.1469,  0.1400]]],
#
#
#         [[[-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           ...,
#           [-0.9898, -0.9898, -0.9914,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9883, -0.9884, -0.9910,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9982, -0.9981, -0.9940,  ..., -0.9922, -0.9922, -0.9922]],
#
#          [[-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           ...,
#           [-0.9898, -0.9898, -0.9914,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9883, -0.9884, -0.9910,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9982, -0.9981, -0.9940,  ..., -0.9922, -0.9922, -0.9922]],
#
#          [[-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           ...,
#           [-0.9898, -0.9898, -0.9914,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9883, -0.9884, -0.9910,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9982, -0.9981, -0.9940,  ..., -0.9922, -0.9922, -0.9922]]]]), 'label': tensor([0, 1, 1, 0, 1])}
# torch.Size([5, 3, 64, 64])
# tensor([0, 1, 1, 0, 1])

# %% [markdown]
# ## Definición del modelo

# %%
class InterpretableConvLayer(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, feature_map_size, tau=0.5, beta=4.0, alpha=0.95):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, padding=1, bias=True)
        self.tau = tau
        self.beta = beta
        self.alpha = alpha
        self.n = feature_map_size
        self.templates = generate_templates(self.n, tau=self.tau, beta=self.beta)

    def forward(self, x):
        x = nn.ReLU()(self.conv(x))
        if not self.training:
            logging.info("Training mode: applying masks to feature maps.")
            masks = self._assign_masks(x)
            masked_x = x * masks
            return masked_x * (masked_x > 0)
        else:
            logging.info("Inference mode: applying templates to feature maps.")
            return x

    def _assign_masks(self, x):

        B, C, H, W = x.shape

        x_flat = x.view(B * C, H, W)
        masks = []

        for fmap in x_flat:
            mu_hat = torch.argmax(fmap.view(-1))
            i, j = mu_hat // self.n, mu_hat % self.n
            idx = i * self.n + j
            mask = self.templates[idx]
            masks.append(mask)

        masks = torch.stack(masks).view(B, C, H, W).to(x.device)
        return masks

# %%
OUTPUT_CHANNELS = len(classes)
INPUT_CHANNELS = X.shape[1]
icnn = InterpretableConvLayer(in_channels=INPUT_CHANNELS, out_channels=OUTPUT_CHANNELS, kernel_size=3, feature_map_size=n, tau=(0.5/(n*n)), beta=4.0)
icnn = icnn.to(device)
icnn
# Out:
# InterpretableConvLayer(
#   (conv): Conv2d(2, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
output = icnn(X.to(device))
output.shape
# Out:
# torch.Size([5, 2, 16, 16])

# %%
class Model(nn.Module):
    def __init__(self, feature_map_size, channels=1, num_classes=10, filters_icnn=6):
        super().__init__()
        filters_cnn=20
        self.cnn = nn.Conv2d(channels, filters_cnn, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.icnn = InterpretableConvLayer(in_channels=filters_cnn, out_channels=filters_icnn, kernel_size=3, feature_map_size=feature_map_size//2, tau=2.00, beta=4.00, alpha=4.00)
        # self.cnn2 = nn.Conv2d(filters_cnn, filters_icnn, kernel_size=3, padding=1)

        input_size = filters_icnn * (feature_map_size // 4) * (feature_map_size // 4)
        self.linear = nn.Linear(3072, 100)
        self.classifier = nn.Linear(100, num_classes)

    def forward(self, x):
        x = self.cnn(x)
        x = self.pool(x)
        x = nn.ReLU()(x)
        x = self.icnn(x)
        # x = self.cnn2(x)
        x = nn.ReLU()(x)
        icnn_output = x
        x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        x = nn.ReLU()(x)
        logits = self.classifier(x)
        # x = torch.softmax(x, dim=1)
        return logits, icnn_output

# %% [markdown]
# ## Training

# %%
INPUT_CHANNELS = 3

# %%
n = trainset[0]['image'].shape[-1]
print("Feature map size n =", n)
model = Model(feature_map_size=n, channels=INPUT_CHANNELS, num_classes=len(classes), filters_icnn=12)
# Out:
# Feature map size n = 64

# %%
trainset[0]['image'].unsqueeze(0).shape
# Out:
# torch.Size([1, 3, 64, 64])

# %% [markdown]
# ## Entrenamiento del modelo

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=3e-1)
criterion = nn.CrossEntropyLoss()

# %%
n
# Out:
# 64

# %%
lambda_ = 1e-2
EPOCHS = 40

losses = {
    "total_loss": [],
    "class_loss": [],
    "interp_loss": []
}

model = Model(feature_map_size=n, channels=3, num_classes=len(classes), filters_icnn=12)
model = model.to(device)
model.train()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-3)
criterion = nn.CrossEntropyLoss()

# keep_icnn_output = 0
# keep_templates = 0
for epoch in trange(EPOCHS):
    losses_epoch = {
        "total_loss": [],
        "class_loss": [],
        "interp_loss": []
    }
    for batch in tqdm(trainloader, desc="Training", leave=False):

        optimizer.zero_grad()
        images, labels = batch['image'].to(device), batch['label'].to(device)
        logits, icnn_output = model(images)

        # print(y_pred.shape, labels.shape)
        # print(labels, "labels")
        # print(y_pred, "y pred")
        class_loss = criterion(logits, labels.long())
        # print(y_pred)


        # batch_size = images.shape[0]
        # templates = model.icnn.templates.unsqueeze(0).to(device)

        # keep_icnn_output = icnn_output.detach().clone()
        # keep_templates = templates.detach().clone()

        # print("icnn output", icnn_output.shape)
        # print("templates", templates.shape)
        # interp_loss = mutual_information(icnn_output, templates, icnn_output.shape[-1], device=device).sum()
        # total_loss = lambda_ * interp_loss + (1 - lambda_) * class_loss
        # total_loss = class_loss
        # print("Interp loss", lambda_ * interp_loss.item())
        # print("Total loss", total_loss.item())

        # losses["class_loss"].append(class_loss.item())
        losses_epoch["class_loss"].append(class_loss.item())

        class_loss.backward()
        optimizer.step()
        # break

    avg_loss = np.mean(losses_epoch["class_loss"])
    print(f"Epoch {epoch+1}/{EPOCHS}, Avg Class Loss: {avg_loss:.4f}")
    # avg_interp_loss = np.mean(losses_epoch["interp_loss
    # print(np.mean(losses["class_loss"]))
    print(class_loss)
    # print(interp_loss)
    # losses["total_loss"].append(total_loss.item())
    losses["class_loss"].append(avg_loss)
    # losses["interp_loss"].append(interp_loss.item())
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 1/40, Avg Class Loss: 0.3857
# tensor(1.1073, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 2/40, Avg Class Loss: 0.3358
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 3/40, Avg Class Loss: 0.3155
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 4/40, Avg Class Loss: 0.3017
# tensor(0.1274, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 5/40, Avg Class Loss: 0.2925
# tensor(0.2544, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 6/40, Avg Class Loss: 0.2807
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 7/40, Avg Class Loss: 0.2684
# tensor(0.4392, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 8/40, Avg Class Loss: 0.2649
# tensor(0.0047, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 9/40, Avg Class Loss: 0.2585
# tensor(0.0253, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 10/40, Avg Class Loss: 0.2498
# tensor(0.0075, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 11/40, Avg Class Loss: 0.2433
# tensor(0.2076, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 12/40, Avg Class Loss: 0.2347
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 13/40, Avg Class Loss: 0.2263
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 14/40, Avg Class Loss: 0.2243
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 15/40, Avg Class Loss: 0.2183
# tensor(0.9184, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 16/40, Avg Class Loss: 0.2145
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 17/40, Avg Class Loss: 0.2062
# tensor(0.0166, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 18/40, Avg Class Loss: 0.1999
# tensor(0.0600, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 19/40, Avg Class Loss: 0.1952
# tensor(1.1921e-07, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 20/40, Avg Class Loss: 0.1941
# tensor(0.0001, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 21/40, Avg Class Loss: 0.1856
# tensor(0.1831, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 22/40, Avg Class Loss: 0.1849
# tensor(0.2037, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 23/40, Avg Class Loss: 0.1795
# tensor(2.2098, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 24/40, Avg Class Loss: 0.1754
# tensor(0.0556, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 25/40, Avg Class Loss: 0.1740
# tensor(0.1728, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 26/40, Avg Class Loss: 0.1635
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 27/40, Avg Class Loss: 0.1637
# tensor(0.1476, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 28/40, Avg Class Loss: 0.1624
# tensor(0.0001, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 29/40, Avg Class Loss: 0.1554
# tensor(2.9802e-06, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 30/40, Avg Class Loss: 0.1531
# tensor(1.1921e-07, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 31/40, Avg Class Loss: 0.1520
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 32/40, Avg Class Loss: 0.1459
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 33/40, Avg Class Loss: 0.1447
# tensor(7.1525e-06, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 34/40, Avg Class Loss: 0.1418
# tensor(0.0084, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 35/40, Avg Class Loss: 0.1416
# tensor(1.0144, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 36/40, Avg Class Loss: 0.1392
# tensor(0.0308, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 37/40, Avg Class Loss: 0.1330
# tensor(0.0515, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 38/40, Avg Class Loss: 0.1350
# tensor(0.0046, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 39/40, Avg Class Loss: 0.1321
# tensor(0.4035, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 40/40, Avg Class Loss: 0.1344
# tensor(1.3113e-06, device='mps:0', grad_fn=<NllLossBackward0>)

# %%
# plt.plot(losses["total_loss"], label="Total Loss")
plt.plot(losses["class_loss"], label="Class Loss")
# plt.plot(losses["interp_loss"], label="Interp Loss")

# %%
rand_i = random.randint(0, len(testset)-1)
rand_item = testset[rand_i]["image"].unsqueeze(0)
rand_item.shape
plot_tensors(rand_item, title="Random Test Image", cmap="gray", show_colorbar=False)

# %%
icnn_filters = model.icnn.conv.weight.data
icnn_filters.shape
# Out:
# torch.Size([12, 20, 3, 3])

# %%
logits, icnn_output = model(rand_item.to(device))
icnn_output.shape
# Out:
# torch.Size([1, 12, 32, 32])

# %%
plot_tensors(icnn_output)
# Out:
# /var/folders/sx/_3f9ftxx24q3hbz_25d1xrjh0000gn/T/ipykernel_25675/2983223761.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 0.95])

# %%
# Evaluate
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for batch in testloader:
        images, labels = batch['image'].to(device), batch['label'].to(device)
        outputs, _ = model(images)
        _, predicted = torch.max(outputs.data, 1)
        # print(predicted)
        # print(labels)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Accuracy of the model on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# Accuracy of the model on the 1188 test images: 75.33670033670033 %
