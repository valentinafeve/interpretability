# %%
import torch
from PIL import Image
from torchvision.io import read_image
from torchvision.io import ImageReadMode
import matplotlib.pyplot as plt
import numpy as np
import torch
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as datasets
from PIL import Image
from torchvision.transforms import (Compose, Normalize, Resize, ToPILImage,
                                    ToTensor)
from tqdm.notebook import tqdm, trange
import numpy as np
import logging
from matplotlib.cm import ScalarMappable
from torchvision import transforms
import torchvision
from matplotlib.colors import Normalize
import random
from datasets import load_dataset
import torch
import numpy as np
import matplotlib.pyplot as plt

import torchvision.transforms.functional as F

# %%
plt.rcParams["savefig.bbox"] = 'tight'


def show(imgs):
    if not isinstance(imgs, list):
        imgs = [imgs]
    fig, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = img.detach()
        img = F.to_pil_image(img)
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
if device == 'cpu':
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# mps

# %%
def save_tensor_as_image(tensor, filename):
    """
    Saves a single tensor as an image file.

    Args:
        tensor (torch.Tensor): A 2D tensor representing the image.
        filename (str): The path where the image will be saved.
    """
    if tensor.dim() != 2:
        raise ValueError("Input tensor must be 2D.")

    array = tensor.cpu().numpy()
    plt.imsave(filename, array, cmap='gray')

# %%
def plot_tensors(tensor, title=None, cmap="magma", show_colorbar=True, save_path=None):
    """
    Plots a batch of filters/images in a nearly square grid.

    The input tensor should have shape (batch_size, filters, height, width).
    Only the first batch element is visualized.

    Args:
        tensor (torch.Tensor or np.ndarray):
            A 4D tensor or array with shape (B, K, H, W).
        title (str, optional):
            Title for the entire grid plot. Defaults to None.
        cmap (str, optional):
            Colormap for visualization. Defaults to "magma".
        show_colorbar (bool, optional):
            Whether to display a shared colorbar. Defaults to True.
        save_path (str, optional):
            File path to save the plot. If None, the plot is not saved.

    Returns:
        None. Displays (and optionally saves) the grid of images.
    """
    if isinstance(tensor, torch.Tensor):
        tensor = tensor.detach().cpu().numpy()

    B, K, H, W = tensor.shape
    imgs = tensor[0]  # (K, H, W)

    vmin, vmax = float(imgs.min()), float(imgs.max())

    # --- cuadrado automático ---
    cols = int(np.ceil(np.sqrt(K)))
    rows = int(np.ceil(K / cols))

    fig, axs = plt.subplots(rows, cols, figsize=(cols * 2, rows * 2))
    axs = np.atleast_2d(axs)

    for i in range(K):
        r, c = divmod(i, cols)
        axs[r, c].imshow(imgs[i], cmap=cmap, vmin=vmin, vmax=vmax)
        axs[r, c].axis("off")

    # Apagar celdas sobrantes
    for j in range(K, rows * cols):
        r, c = divmod(j, cols)
        axs[r, c].axis("off")

    # Colorbar compartida
    if show_colorbar:
        cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
        norm = Normalize(vmin=vmin, vmax=vmax)
        sm = ScalarMappable(cmap=cmap, norm=norm)
        sm.set_array([])
        cbar = fig.colorbar(sm, cax=cbar_ax)
        cbar.set_ticks([vmin, vmax])

    if title:
        fig.suptitle(title, fontsize=14)

    plt.tight_layout(rect=[0, 0, 0.9, 0.95])

    if save_path:
        plt.savefig(save_path, bbox_inches="tight", dpi=150)

    plt.show()
    plt.close()
    return save_path

# %%
import torch

def generate_templates(n: int, tau: float = 0.5, beta: float = 4.0):
    """
    Generates n^2 positive templates and one negative template
    for an interpretable CNN, as described in Zhang et al. (2018).

    Each positive template corresponds to a potential spatial position
    in an n x n feature map. Values decay according to the L1 distance
    from the central position. A negative template is also generated
    to represent the absence of activation.

    Args:
        n (int): Size of the feature map (n x n).
        tau (float, optional): Scaling constant for maximum activation value.
            Defaults to 0.5.
        beta (float, optional): Decay factor based on L1 distance.
            Defaults to 4.0.

    Returns:
        tuple:
            templates_pos (list[torch.Tensor]): List of n^2 positive templates
                (each of shape n x n).
            template_neg (torch.Tensor): Negative template of shape n x n
                filled with -tau.

    Example:
        >>> templates_pos, template_neg = generate_templates(4)
        >>> len(templates_pos)
        16
        >>> template_neg.shape
        torch.Size([4, 4])
    """
    templates_pos = []
    coords = [(i, j) for i in range(n) for j in range(n)]

    for mu in coords:
        template = torch.zeros((n, n))
        for i in range(n):
            for j in range(n):
                dist = abs(i - mu[0]) + abs(j - mu[1])  # L1 distance
                value = tau * max(1 - beta * dist / n, -1)
                template[i, j] = value
        templates_pos.append(template)

    template_neg = torch.full((n, n), -tau)

    templates = torch.stack(templates_pos + [template_neg], dim=0)
    return templates


# Quick test
n = 16
templates = generate_templates(n, tau = (0.5/(n*n)), beta=4.0)

# %%
templates[[0]].sum()
# Out:
# tensor(-0.4414)

# %%
templates.shape
# Out:
# torch.Size([257, 16, 16])

# %%
plot_tensors(templates[:-1].unsqueeze(0), title="Templates")
# Out:
# /var/folders/sx/_3f9ftxx24q3hbz_25d1xrjh0000gn/T/ipykernel_77700/2983223761.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 0.95])

# %%
T = torch.randn(1, (n*n+1), n, n)
X = torch.randn(5, 2, n, n)

# %%
def mutual_information(X: torch.Tensor, templates: torch.Tensor, n, device='cpu'):
    atol = 1/(n*n)
    rtol = 1/(n*n)
    X_expanded = X.unsqueeze(2)
    T_expanded = templates.unsqueeze(1).expand(-1, n*n, -1, -1)

    XT = torch.mul(X_expanded, T_expanded)
    s_max = XT.max(dim=-1)[0].max(dim=-1)[0]
    s_min = XT.min(dim=-1)[0].min(dim=-1)[0]
    # print(s_max)
    # print(s_min)
    # XT = XT / s_max.unsqueeze(-1).unsqueeze(-1)
    trace = XT.sum(dim=(-1, -2))
    exp = torch.exp(trace)

    # print(exp.shape)
    ZT = exp.sum(dim=1, keepdim=True)

    pXT = exp / ZT # (2 , 257)

    pT = torch.full((1, (n*n+1)), 1/(1+n*n)).to(device) # (1 , 257)
    pX = ((torch.mul(pXT,pT)).sum(dim=1)) # (2)
    sum_pX = pX.sum(dim=1)
    one = torch.tensor(1.0, device=pT.device, dtype=pT.dtype)
    assert torch.allclose(sum_pX, one, rtol=rtol, atol=atol), "sum_x p(x) debe ser 1"


    eps_box = 1e-7
    assert (pXT >= -eps_box).all() and (pXT <= 1+eps_box).all(), "Valores fuera de [0,1] en p(x|T)"
    assert (pX  >= -eps_box).all() and (pX  <= 1+eps_box).all(), "Valores fuera de [0,1] en p(x)"
    eps = 1e-12
    ratio = pXT.clamp_min(eps) / pX.unsqueeze(1).clamp_min(eps)
    MI = ((pT) * (pXT * torch.log(ratio)).sum(dim=-2)).sum(dim=-1)
    return MI

# %%
MI = mutual_information(X, T, X.shape[-1])
MI
# Out:
# tensor([5.4985, 5.4832, 5.4772, 5.5001, 5.4890])

# %% [markdown]
# ## Preparación de los datos

# %%
DESIRED_SHAPE = 64
transform = transforms.Compose(
    [  
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
        # transforms.Normalize((0.5), (0.5)),
        transforms.Resize((DESIRED_SHAPE, DESIRED_SHAPE)),
        transforms.CenterCrop((DESIRED_SHAPE, DESIRED_SHAPE)),
        # transforms.ColorJitter(brightness=1.8),
    ]    
    )

batch_size = 5

dataset = load_dataset("Hemg/Melanoma-Cancer-Image-Dataset", split="train")
trainset, testset = dataset.train_test_split(test_size=0.1, seed=42).values()

# %%
trainset = trainset.with_format("torch")
testset  = testset.with_format("torch")

# %%
trainset[0]
# Out:
# {'image': tensor([[[150, 150, 149,  ..., 149, 131, 134],
#           [151, 151, 151,  ..., 127, 127, 152],
#           [152, 151, 151,  ..., 121, 137, 123],
#           ...,
#           [147, 147, 148,  ..., 136, 136, 137],
#           [146, 146, 146,  ..., 135, 135, 135],
#           [145, 145, 146,  ..., 136, 136, 136]],
#
#          [[119, 119, 118,  ..., 122, 104, 107],
#           [120, 120, 120,  ..., 100, 100, 125],
#           [121, 120, 120,  ...,  94, 110,  96],
#           ...,
#           [114, 114, 115,  ..., 105, 105, 106],
#           [113, 113, 113,  ..., 104, 104, 104],
#           [112, 112, 113,  ..., 105, 105, 105]],
#
#          [[124, 124, 123,  ..., 127, 109, 112],
#           [125, 125, 125,  ..., 105, 105, 130],
#           [126, 125, 125,  ...,  99, 115, 101],
#           ...,
#           [121, 121, 122,  ..., 111, 111, 112],
#           [120, 120, 120,  ..., 110, 110, 110],
#           [119, 119, 120,  ..., 111, 111, 111]]], dtype=torch.uint8),
#  'label': tensor(1)}

# %%
trainset = trainset.with_transform(lambda examples: {'image': [transform(img) for img in examples['image']], 'label': examples['label']})

# %%
testset = testset.with_transform(lambda examples: {'image': [transform(img) for img in examples['image']], 'label': examples['label']})

# %%
testset
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 1188
# })

# %%
trainset[0]['image']
# Out:
# tensor([[[ 0.1754,  0.1865,  0.1779,  ...,  0.1559,  0.1148,  0.0192],
#          [ 0.1543,  0.1750,  0.1776,  ...,  0.1677,  0.0998, -0.2025],
#          [ 0.1896,  0.1844,  0.1747,  ...,  0.1802,  0.0843, -0.0538],
#          ...,
#          [ 0.1505,  0.1734,  0.1791,  ...,  0.1200,  0.1369,  0.1283],
#          [ 0.1644,  0.1811,  0.1811,  ...,  0.0984,  0.0918,  0.0854],
#          [ 0.1534,  0.1701,  0.1812,  ...,  0.0889,  0.0859,  0.0703]],
#
#         [[-0.0678, -0.0567, -0.0652,  ..., -0.0857, -0.1097, -0.1936],
#          [-0.0889, -0.0681, -0.0655,  ..., -0.0738, -0.1248, -0.4153],
#          [-0.0535, -0.0587, -0.0684,  ..., -0.0613, -0.1403, -0.2667],
#          ...,
#          [-0.1083, -0.0854, -0.0798,  ..., -0.1232, -0.1063, -0.1149],
#          [-0.0944, -0.0777, -0.0777,  ..., -0.1447, -0.1513, -0.1578],
#          [-0.1054, -0.0887, -0.0776,  ..., -0.1542, -0.1572, -0.1729]],
#
#         [[-0.0286, -0.0174, -0.0260,  ..., -0.0394, -0.0703, -0.1544],
#          [-0.0496, -0.0289, -0.0263,  ..., -0.0276, -0.0854, -0.3761],
#          [-0.0143, -0.0195, -0.0292,  ..., -0.0151, -0.1009, -0.2275],
#          ...,
#          [-0.0534, -0.0305, -0.0249,  ..., -0.0761, -0.0592, -0.0678],
#          [-0.0395, -0.0228, -0.0228,  ..., -0.0977, -0.1042, -0.1107],
#          [-0.0505, -0.0338, -0.0227,  ..., -0.1071, -0.1102, -0.1258]]])

# %%
classes = trainset.features['label'].names
classes
# Out:
# ['Benign', 'Malignant']

# %%
print("Dataset loaded with {} classes of values {}".format(len(classes), ', '.join(classes)))
# Dataset loaded with 2 classes of values Benign, Malignant
# Out:
# Dataset loaded with 2 classes of values Benign, Malignant

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=0)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=0)

# %%
cont = 0
for batch in trainloader:
    print(batch)
    print(batch['image'].shape)
    show(torchvision.utils.make_grid(batch['image']))
    print(batch['label'])
    cont+=1
    if cont==5:
        break
# Out:
# {'image': tensor([[[[ 0.4915,  0.5558,  0.6077,  ...,  0.7076,  0.6881,  0.6610],
#           [ 0.5198,  0.5658,  0.6216,  ...,  0.7328,  0.7013,  0.6780],
#           [ 0.5513,  0.5875,  0.6351,  ...,  0.7501,  0.7072,  0.6863],
#           ...,
#           [ 0.4770,  0.5201,  0.5545,  ...,  0.6089,  0.5658,  0.5398],
#           [ 0.4298,  0.4764,  0.5298,  ...,  0.5874,  0.5553,  0.5209],
#           [ 0.4055,  0.4498,  0.5035,  ...,  0.5508,  0.5380,  0.5109]],
#
#          [[ 0.1856,  0.2423,  0.2702,  ...,  0.4488,  0.4292,  0.4021],
#           [ 0.2112,  0.2483,  0.2845,  ...,  0.4739,  0.4425,  0.4192],
#           [ 0.2377,  0.2667,  0.2976,  ...,  0.4913,  0.4483,  0.4275],
#           ...,
#           [ 0.2328,  0.2713,  0.2927,  ...,  0.3344,  0.2913,  0.2653],
#           [ 0.2047,  0.2436,  0.2755,  ...,  0.3129,  0.2808,  0.2464],
#           [ 0.1855,  0.2226,  0.2579,  ...,  0.2763,  0.2635,  0.2364]],
#
#          [[ 0.3396,  0.4138,  0.4773,  ...,  0.5351,  0.5155,  0.4884],
#           [ 0.3826,  0.4336,  0.4916,  ...,  0.5602,  0.5287,  0.5055],
#           [ 0.4379,  0.4698,  0.5044,  ...,  0.5776,  0.5346,  0.5138],
#           ...,
#           [ 0.4389,  0.4390,  0.4534,  ...,  0.5227,  0.4795,  0.4535],
#           [ 0.4028,  0.4365,  0.4727,  ...,  0.5012,  0.4690,  0.4346],
#           [ 0.3784,  0.4310,  0.4768,  ...,  0.4645,  0.4518,  0.4246]]],
#
#
#         [[[ 0.5903,  0.5969,  0.6051,  ...,  0.8286,  0.8272,  0.8207],
#           [ 0.5749,  0.5963,  0.5924,  ...,  0.8155,  0.8147,  0.8190],
#           [ 0.5732,  0.5842,  0.5715,  ...,  0.8109,  0.8037,  0.8098],
#           ...,
#           [ 0.5985,  0.5962,  0.6073,  ...,  0.7092,  0.7009,  0.7120],
#           [ 0.5903,  0.5818,  0.5915,  ...,  0.7175,  0.7024,  0.7024],
#           [ 0.5957,  0.6037,  0.6155,  ...,  0.7241,  0.7189,  0.7029]],
#
#          [[-0.0373, -0.0308, -0.0225,  ...,  0.2875,  0.2861,  0.2795],
#           [-0.0375, -0.0161, -0.0200,  ...,  0.2744,  0.2735,  0.2779],
#           [-0.0217, -0.0107, -0.0234,  ...,  0.2697,  0.2625,  0.2686],
#           ...,
#           [ 0.1152,  0.1130,  0.1240,  ...,  0.2066,  0.2174,  0.2403],
#           [ 0.0933,  0.0848,  0.0945,  ...,  0.2149,  0.2189,  0.2307],
#           [ 0.0870,  0.0950,  0.1068,  ...,  0.2215,  0.2354,  0.2312]],
#
#          [[ 0.2099,  0.2164,  0.2246,  ...,  0.4286,  0.4272,  0.4207],
#           [ 0.2032,  0.2247,  0.2207,  ...,  0.4155,  0.4147,  0.4190],
#           [ 0.2137,  0.2247,  0.2120,  ...,  0.4109,  0.4037,  0.4098],
#           ...,
#           [ 0.1725,  0.1703,  0.1813,  ...,  0.2356,  0.2395,  0.2565],
#           [ 0.1559,  0.1473,  0.1571,  ...,  0.2439,  0.2410,  0.2470],
#           [ 0.1498,  0.1578,  0.1695,  ...,  0.2505,  0.2575,  0.2474]]],
#
#
#         [[[-0.8214, -0.7388, -0.4475,  ..., -0.5782, -0.5979, -0.5427],
#           [-0.8009, -0.5922, -0.3032,  ..., -0.5159, -0.5854, -0.5789],
#           [-0.7398, -0.4243, -0.1842,  ..., -0.4417, -0.5386, -0.5972],
#           ...,
#           [-0.8347, -0.6553, -0.2943,  ..., -0.4051, -0.4639, -0.5119],
#           [-0.8533, -0.7917, -0.4378,  ..., -0.4410, -0.5091, -0.5485],
#           [-0.8760, -0.8421, -0.6143,  ..., -0.4757, -0.5469, -0.5993]],
#
#          [[-0.8596, -0.7861, -0.5524,  ..., -0.8092, -0.8004, -0.7223],
#           [-0.8692, -0.6799, -0.4478,  ..., -0.7699, -0.8096, -0.7823],
#           [-0.8334, -0.5643, -0.3945,  ..., -0.7252, -0.7948, -0.8340],
#           ...,
#           [-0.9169, -0.8021, -0.5407,  ..., -0.6466, -0.6884, -0.7248],
#           [-0.9044, -0.8794, -0.6174,  ..., -0.6826, -0.7337, -0.7614],
#           [-0.9092, -0.8994, -0.7541,  ..., -0.7172, -0.7715, -0.8121]],
#
#          [[-0.8901, -0.7995, -0.5709,  ..., -0.8920, -0.8793, -0.8052],
#           [-0.8552, -0.6813, -0.4971,  ..., -0.8447, -0.8807, -0.8556],
#           [-0.8075, -0.5849, -0.4801,  ..., -0.7909, -0.8554, -0.8957],
#           ...,
#           [-0.9188, -0.8708, -0.6695,  ..., -0.6883, -0.7369, -0.7791],
#           [-0.9057, -0.9258, -0.7114,  ..., -0.7242, -0.7822, -0.8157],
#           [-0.9104, -0.9287, -0.8238,  ..., -0.7588, -0.8200, -0.8665]]],
#
#
#         [[[ 0.0663,  0.0835,  0.1023,  ...,  0.1772,  0.1452,  0.1134],
#           [ 0.0882,  0.1058,  0.1168,  ...,  0.2062,  0.1805,  0.1522],
#           [ 0.1212,  0.1410,  0.1477,  ...,  0.2283,  0.1967,  0.1877],
#           ...,
#           [ 0.1861,  0.1987,  0.2094,  ...,  0.2269,  0.1981,  0.1822],
#           [ 0.1622,  0.1656,  0.1803,  ...,  0.2074,  0.1744,  0.1464],
#           [ 0.1435,  0.1517,  0.1639,  ...,  0.1835,  0.1417,  0.1184]],
#
#          [[-0.0278, -0.0106,  0.0082,  ...,  0.0674,  0.0354,  0.0036],
#           [-0.0059,  0.0117,  0.0227,  ...,  0.0964,  0.0707,  0.0423],
#           [ 0.0271,  0.0469,  0.0536,  ...,  0.1185,  0.0869,  0.0779],
#           ...,
#           [ 0.0499,  0.0624,  0.0732,  ...,  0.1328,  0.1039,  0.0880],
#           [ 0.0397,  0.0432,  0.0578,  ...,  0.1133,  0.0802,  0.0523],
#           [ 0.0379,  0.0461,  0.0583,  ...,  0.0894,  0.0476,  0.0243]],
#
#          [[-0.0278, -0.0106,  0.0082,  ...,  0.0439,  0.0119, -0.0199],
#           [-0.0059,  0.0117,  0.0227,  ...,  0.0729,  0.0472,  0.0188],
#           [ 0.0271,  0.0469,  0.0536,  ...,  0.0949,  0.0634,  0.0544],
#           ...,
#           [ 0.0968,  0.1093,  0.1201,  ...,  0.1485,  0.1196,  0.1037],
#           [ 0.0814,  0.0848,  0.0994,  ...,  0.1290,  0.0959,  0.0680],
#           [ 0.0731,  0.0813,  0.0935,  ...,  0.1050,  0.0633,  0.0400]]],
#
#
#         [[[ 0.3946,  0.4153,  0.4989,  ...,  0.5342,  0.5035,  0.4803],
#           [ 0.4044,  0.4272,  0.5329,  ...,  0.5404,  0.5201,  0.4787],
#           [ 0.4576,  0.4898,  0.5192,  ...,  0.5403,  0.5236,  0.4878],
#           ...,
#           [ 0.2596,  0.3176,  0.4178,  ...,  0.5237,  0.4885,  0.4370],
#           [ 0.3119,  0.3606,  0.3838,  ...,  0.5122,  0.4877,  0.4128],
#           [ 0.3111,  0.3445,  0.3478,  ...,  0.4882,  0.4553,  0.3912]],
#
#          [[-0.0905, -0.0466,  0.0658,  ...,  0.1702,  0.1225,  0.0887],
#           [-0.0549, -0.0193,  0.1083,  ...,  0.1764,  0.1391,  0.0871],
#           [ 0.0320,  0.0700,  0.1072,  ...,  0.1763,  0.1426,  0.0962],
#           ...,
#           [-0.1366, -0.0487,  0.0818,  ...,  0.2185,  0.1779,  0.1186],
#           [-0.0878, -0.0072,  0.0489,  ...,  0.2051,  0.1742,  0.0920],
#           [-0.0958, -0.0271,  0.0156,  ...,  0.1785,  0.1402,  0.0701]],
#
#          [[-0.2050, -0.1245,  0.0474,  ...,  0.0596,  0.0129,  0.0088],
#           [-0.1525, -0.0835,  0.0965,  ...,  0.0658,  0.0295,  0.0072],
#           [-0.0373,  0.0255,  0.1025,  ...,  0.0657,  0.0330,  0.0163],
#           ...,
#           [-0.1248,  0.0010,  0.1574,  ...,  0.1658,  0.1570,  0.1411],
#           [-0.0578,  0.0519,  0.1217,  ...,  0.1674,  0.1713,  0.1348],
#           [-0.0227,  0.0546,  0.0810,  ...,  0.1512,  0.1472,  0.1219]]]]), 'label': tensor([0, 0, 1, 1, 0])}
# torch.Size([5, 3, 64, 64])
# tensor([0, 0, 1, 1, 0])
# {'image': tensor([[[[ 5.8039e-01,  6.1625e-01,  5.8608e-01,  ...,  5.1906e-01,
#             5.0266e-01,  5.1106e-01],
#           [ 5.7335e-01,  5.7170e-01,  5.6121e-01,  ...,  5.2252e-01,
#             4.7646e-01,  5.0621e-01],
#           [ 5.8054e-01,  5.7286e-01,  5.8326e-01,  ...,  5.3854e-01,
#             4.9990e-01,  5.3222e-01],
#           ...,
#           [ 5.2331e-01,  5.7964e-01,  5.6484e-01,  ...,  4.5286e-01,
#             4.5073e-01,  4.1078e-01],
#           [ 5.2735e-01,  5.5518e-01,  5.4645e-01,  ...,  4.6971e-01,
#             4.7206e-01,  3.9977e-01],
#           [ 5.5033e-01,  5.5926e-01,  5.5584e-01,  ...,  4.7887e-01,
#             4.4743e-01,  3.8016e-01]],
#
#          [[-2.0139e-01, -1.2950e-01, -1.4768e-01,  ..., -7.7900e-01,
#            -8.0020e-01, -7.8066e-01],
#           [-2.3202e-01, -1.9987e-01, -1.9769e-01,  ..., -7.6130e-01,
#            -8.1272e-01, -7.5862e-01],
#           [-2.2195e-01, -1.9635e-01, -1.7261e-01,  ..., -7.1717e-01,
#            -7.6890e-01, -6.8612e-01],
#           ...,
#           [-3.6422e-01, -3.6067e-01, -4.2805e-01,  ..., -6.1347e-01,
#            -6.0244e-01, -6.1082e-01],
#           [-3.8162e-01, -4.3311e-01, -4.9014e-01,  ..., -6.2910e-01,
#            -6.0166e-01, -6.3230e-01],
#           [-3.5422e-01, -4.3302e-01, -4.7983e-01,  ..., -6.6873e-01,
#            -6.6141e-01, -6.8248e-01]],
#
#          [[-3.1783e-01, -2.4456e-01, -2.5045e-01,  ..., -7.5199e-01,
#            -7.5476e-01, -7.2975e-01],
#           [-3.3808e-01, -3.0509e-01, -2.9296e-01,  ..., -7.3822e-01,
#            -7.7267e-01, -7.1660e-01],
#           [-3.2919e-01, -3.0228e-01, -2.6890e-01,  ..., -7.0427e-01,
#            -7.3569e-01, -6.5997e-01],
#           ...,
#           [-4.7260e-01, -4.4551e-01, -4.7699e-01,  ..., -6.3726e-01,
#            -6.4886e-01, -6.8638e-01],
#           [-4.8289e-01, -5.0132e-01, -5.2345e-01,  ..., -6.4758e-01,
#            -6.2948e-01, -6.7716e-01],
#           [-4.5665e-01, -5.0018e-01, -5.1354e-01,  ..., -6.7079e-01,
#            -6.7079e-01, -7.0473e-01]]],
#
#
#         [[[ 5.2532e-01,  5.7640e-01,  5.9596e-01,  ...,  6.5856e-01,
#             6.4449e-01,  6.1841e-01],
#           [ 5.3371e-01,  5.8501e-01,  6.2273e-01,  ...,  6.7933e-01,
#             6.5284e-01,  6.2723e-01],
#           [ 5.5573e-01,  6.0136e-01,  6.4108e-01,  ...,  6.9680e-01,
#             6.6799e-01,  6.4362e-01],
#           ...,
#           [ 5.0752e-01,  5.3501e-01,  5.6657e-01,  ...,  7.0910e-01,
#             6.8576e-01,  6.7199e-01],
#           [ 5.1221e-01,  5.4236e-01,  5.7463e-01,  ...,  6.9781e-01,
#             6.6055e-01,  6.4888e-01],
#           [ 5.0215e-01,  5.4961e-01,  5.7303e-01,  ...,  6.6771e-01,
#             6.4263e-01,  6.3206e-01]],
#
#          [[ 2.2728e-01,  2.7836e-01,  2.9792e-01,  ...,  3.7620e-01,
#             3.6213e-01,  3.3606e-01],
#           [ 2.3567e-01,  2.8697e-01,  3.2469e-01,  ...,  3.9698e-01,
#             3.7049e-01,  3.4488e-01],
#           [ 2.5769e-01,  3.0332e-01,  3.4304e-01,  ...,  4.1445e-01,
#             3.8564e-01,  3.6127e-01],
#           ...,
#           [ 2.0948e-01,  2.3697e-01,  2.6853e-01,  ...,  4.4243e-01,
#             4.1910e-01,  4.0532e-01],
#           [ 2.1417e-01,  2.4432e-01,  2.7659e-01,  ...,  4.3115e-01,
#             3.9388e-01,  3.8221e-01],
#           [ 2.0411e-01,  2.5157e-01,  2.7500e-01,  ...,  4.0104e-01,
#             3.7597e-01,  3.6540e-01]],
#
#          [[ 3.1355e-01,  3.6463e-01,  3.8420e-01,  ...,  4.7032e-01,
#             4.5625e-01,  4.3018e-01],
#           [ 3.2195e-01,  3.7325e-01,  4.1096e-01,  ...,  4.9109e-01,
#             4.6461e-01,  4.3900e-01],
#           [ 3.4396e-01,  3.8959e-01,  4.2932e-01,  ...,  5.0856e-01,
#             4.7976e-01,  4.5539e-01],
#           ...,
#           [ 2.9575e-01,  3.2324e-01,  3.5480e-01,  ...,  5.6792e-01,
#             5.4459e-01,  5.3081e-01],
#           [ 3.0044e-01,  3.3059e-01,  3.6286e-01,  ...,  5.5664e-01,
#             5.1937e-01,  5.0770e-01],
#           [ 2.9039e-01,  3.3784e-01,  3.6127e-01,  ...,  5.2653e-01,
#             5.0146e-01,  4.9089e-01]]],
#
#
#         [[[ 1.2234e-01,  7.0307e-02,  1.2628e-01,  ...,  3.7044e-01,
#             3.0736e-01,  3.0810e-01],
#           [ 1.1513e-01,  6.5422e-02,  1.6462e-01,  ...,  3.6442e-01,
#             3.3885e-01,  3.2618e-01],
#           [ 9.4611e-02,  9.2362e-02,  1.9458e-01,  ...,  3.0110e-01,
#             3.6954e-01,  3.1767e-01],
#           ...,
#           [ 9.0661e-02,  1.8961e-01,  2.7072e-01,  ...,  1.0143e-01,
#             1.3086e-01,  1.5477e-01],
#           [ 8.7013e-02,  1.4804e-01,  2.4246e-01,  ...,  8.0341e-02,
#             1.5415e-01,  1.5108e-01],
#           [ 9.6203e-02,  1.3595e-01,  2.1450e-01,  ...,  9.7380e-02,
#             1.4695e-01,  1.3902e-01]],
#
#          [[ 4.6894e-03, -4.7180e-02,  1.4076e-02,  ...,  2.4207e-01,
#             1.9276e-01,  2.0231e-01],
#           [-2.5145e-03, -5.2065e-02,  5.2414e-02,  ...,  2.3605e-01,
#             2.2424e-01,  2.2039e-01],
#           [-2.3036e-02, -2.5125e-02,  8.2376e-02,  ...,  1.7272e-01,
#             2.5493e-01,  2.1188e-01],
#           ...,
#           [ 8.6177e-04,  8.5577e-02,  1.5781e-01,  ..., -3.4624e-02,
#             1.3849e-02,  4.8978e-02],
#           [-7.4579e-03,  4.3598e-02,  1.2930e-01,  ..., -5.5714e-02,
#             3.7143e-02,  4.5293e-02],
#           [-5.7898e-04,  3.2785e-02,  1.0172e-01,  ..., -3.8674e-02,
#             2.9941e-02,  3.3224e-02]],
#
#          [[-3.5621e-02, -9.9201e-02, -5.4911e-02,  ...,  1.3883e-01,
#             1.0168e-01,  1.2406e-01],
#           [-4.2825e-02, -1.0409e-01, -1.6573e-02,  ...,  1.3281e-01,
#             1.3317e-01,  1.4214e-01],
#           [-6.3346e-02, -7.7146e-02,  1.3388e-02,  ...,  6.9483e-02,
#             1.6386e-01,  1.3363e-01],
#           ...,
#           [-7.2518e-02,  1.2983e-02,  7.2602e-02,  ..., -9.5929e-02,
#            -5.4338e-02, -2.1610e-02],
#           [-5.1111e-02, -2.7889e-02,  3.5268e-02,  ..., -1.1702e-01,
#            -3.1044e-02, -2.5296e-02],
#           [-2.5474e-02, -4.1246e-02,  2.0008e-03,  ..., -9.9979e-02,
#            -3.8246e-02, -3.7364e-02]]],
#
#
#         [[[ 8.2972e-02,  2.1349e-01,  2.6978e-01,  ...,  6.2174e-01,
#             5.8661e-01,  4.3926e-01],
#           [ 2.2154e-01,  3.1238e-01,  3.3374e-01,  ...,  5.6532e-01,
#             4.7072e-01,  3.5605e-01],
#           [ 3.2322e-01,  3.5123e-01,  3.3013e-01,  ...,  4.8087e-01,
#             4.0509e-01,  3.5801e-01],
#           ...,
#           [ 7.4171e-01,  7.4854e-01,  7.8102e-01,  ...,  6.2242e-01,
#             6.8845e-01,  6.7692e-01],
#           [ 7.8244e-01,  7.7857e-01,  7.7062e-01,  ...,  6.3782e-01,
#             6.6429e-01,  6.8688e-01],
#           [ 7.1896e-01,  7.7360e-01,  7.0909e-01,  ...,  6.3755e-01,
#             6.7322e-01,  6.6855e-01]],
#
#          [[-1.4662e-02,  9.4592e-02,  1.2924e-01,  ...,  3.9626e-01,
#             4.0802e-01,  3.1407e-01],
#           [ 1.0304e-01,  1.8319e-01,  1.9100e-01,  ...,  3.3504e-01,
#             2.8256e-01,  2.1860e-01],
#           [ 1.7617e-01,  2.0795e-01,  1.8981e-01,  ...,  2.4086e-01,
#             2.0387e-01,  2.0789e-01],
#           ...,
#           [ 5.7686e-01,  5.7643e-01,  5.8783e-01,  ...,  4.2335e-01,
#             4.7074e-01,  4.4530e-01],
#           [ 6.1244e-01,  6.0464e-01,  5.7742e-01,  ...,  4.2014e-01,
#             4.3424e-01,  4.4408e-01],
#           [ 5.4436e-01,  5.9817e-01,  5.1589e-01,  ...,  4.1197e-01,
#             4.3543e-01,  4.1737e-01]],
#
#          [[-6.9649e-02,  4.8163e-02,  8.9109e-02,  ...,  3.7936e-01,
#             4.0673e-01,  3.1476e-01],
#           [ 8.2055e-02,  1.6500e-01,  1.7759e-01,  ...,  3.1394e-01,
#             2.7643e-01,  2.1739e-01],
#           [ 1.7587e-01,  2.0554e-01,  1.8603e-01,  ...,  2.0785e-01,
#             1.8762e-01,  1.9438e-01],
#           ...,
#           [ 5.5538e-01,  5.5528e-01,  5.5972e-01,  ...,  3.8296e-01,
#             4.3542e-01,  4.3513e-01],
#           [ 6.2147e-01,  5.9979e-01,  5.4902e-01,  ...,  3.8522e-01,
#             4.0168e-01,  4.3822e-01],
#           [ 5.7278e-01,  6.0121e-01,  4.8679e-01,  ...,  3.7875e-01,
#             4.0635e-01,  4.1313e-01]]],
#
#
#         [[[-1.7649e-01, -1.0047e-01, -9.1004e-02,  ...,  5.4130e-02,
#             3.2201e-02, -3.4212e-02],
#           [-1.6864e-01, -9.1986e-02, -7.2008e-02,  ...,  8.2569e-02,
#             5.4381e-02,  1.1112e-03],
#           [-1.5836e-01, -7.6862e-02, -5.9545e-02,  ...,  9.7696e-02,
#             5.2294e-02,  2.1834e-02],
#           ...,
#           [-2.5324e-01, -1.8131e-01, -1.4378e-01,  ..., -3.3282e-02,
#            -6.4008e-02, -1.0449e-01],
#           [-2.6347e-01, -2.0251e-01, -1.6136e-01,  ..., -6.7369e-02,
#            -7.3595e-02, -1.0693e-01],
#           [-2.6711e-01, -2.4027e-01, -1.9435e-01,  ..., -6.3920e-02,
#            -7.9345e-02, -1.0507e-01]],
#
#          [[-3.4144e-01, -3.6706e-01, -3.2594e-01,  ..., -2.1597e-01,
#            -2.6558e-01, -3.4601e-01],
#           [-3.3644e-01, -3.6124e-01, -3.0944e-01,  ..., -1.7858e-01,
#            -2.2282e-01, -2.8549e-01],
#           [-3.3129e-01, -3.5183e-01, -3.0241e-01,  ..., -1.5210e-01,
#            -1.9018e-01, -2.2249e-01],
#           ...,
#           [-3.7298e-01, -3.4562e-01, -3.5064e-01,  ..., -2.2695e-01,
#            -2.7623e-01, -3.5044e-01],
#           [-3.6502e-01, -3.5664e-01, -3.6719e-01,  ..., -2.6097e-01,
#            -2.8291e-01, -3.5014e-01],
#           [-3.5686e-01, -3.8481e-01, -3.9808e-01,  ..., -2.5923e-01,
#            -2.8447e-01, -3.4188e-01]],
#
#          [[-4.8482e-01, -5.1227e-01, -4.9167e-01,  ..., -2.8711e-01,
#            -3.1349e-01, -3.8227e-01],
#           [-4.5952e-01, -4.8705e-01, -4.5940e-01,  ..., -2.5153e-01,
#            -2.7750e-01, -3.3189e-01],
#           [-4.2671e-01, -4.4112e-01, -4.1558e-01,  ..., -2.2806e-01,
#            -2.5492e-01, -2.8141e-01],
#           ...,
#           [-4.7244e-01, -4.6917e-01, -4.8496e-01,  ..., -3.0923e-01,
#            -3.2155e-01, -3.7704e-01],
#           [-4.4518e-01, -4.7010e-01, -5.0857e-01,  ..., -3.3991e-01,
#            -3.4314e-01, -3.9498e-01],
#           [-4.2747e-01, -4.9316e-01, -5.3678e-01,  ..., -3.2934e-01,
#            -3.7179e-01, -4.2676e-01]]]]), 'label': tensor([1, 0, 1, 1, 0])}
# torch.Size([5, 3, 64, 64])
# tensor([1, 0, 1, 1, 0])
# {'image': tensor([[[[ 6.0010e-01,  5.4951e-01,  5.7121e-01,  ...,  5.3789e-01,
#             4.8982e-01,  4.0031e-01],
#           [ 6.2030e-01,  5.8098e-01,  5.6924e-01,  ...,  5.1736e-01,
#             4.9288e-01,  4.2383e-01],
#           [ 5.6876e-01,  5.4048e-01,  5.0500e-01,  ...,  5.0380e-01,
#             5.0596e-01,  4.3515e-01],
#           ...,
#           [-2.9716e-01, -3.6087e-01, -4.6374e-01,  ...,  4.2769e-01,
#             4.7888e-01,  5.9700e-01],
#           [-3.2220e-01, -3.2637e-01, -3.8571e-01,  ...,  4.0412e-01,
#             4.2131e-01,  4.4027e-01],
#           [-3.2722e-01, -3.4262e-01, -3.3183e-01,  ...,  3.8244e-01,
#             3.9533e-01,  3.8261e-01]],
#
#          [[ 2.5244e-01,  1.7702e-01,  1.8521e-01,  ...,  2.6098e-01,
#             2.4796e-01,  1.7231e-01],
#           [ 2.6699e-01,  1.9983e-01,  1.7101e-01,  ...,  2.4045e-01,
#             2.5102e-01,  1.9583e-01],
#           [ 2.0382e-01,  1.4585e-01,  9.4835e-02,  ...,  2.2689e-01,
#             2.6410e-01,  2.0715e-01],
#           ...,
#           [-4.8540e-01, -5.4910e-01, -6.5197e-01,  ...,  8.3712e-02,
#             1.7369e-01,  3.2387e-01],
#           [-5.1043e-01, -5.1460e-01, -5.7395e-01,  ...,  6.0143e-02,
#             1.1401e-01,  1.5829e-01],
#           [-5.1545e-01, -5.3085e-01, -5.2006e-01,  ...,  3.8466e-02,
#             8.7847e-02,  9.9893e-02]],
#
#          [[ 1.2430e-01,  3.4695e-02,  5.0143e-02,  ...,  1.9231e-01,
#             1.8281e-01,  1.0956e-01],
#           [ 1.3050e-01,  4.9772e-02,  2.9999e-02,  ...,  1.7178e-01,
#             1.8588e-01,  1.3309e-01],
#           [ 5.5965e-02, -1.4287e-02, -5.7811e-02,  ...,  1.5822e-01,
#             1.9895e-01,  1.4441e-01],
#           ...,
#           [-5.1677e-01, -5.8048e-01, -6.8334e-01,  ..., -3.0894e-02,
#             9.6383e-02,  2.9122e-01],
#           [-5.4180e-01, -5.4598e-01, -6.0532e-01,  ..., -5.4463e-02,
#             3.6696e-02,  1.2564e-01],
#           [-5.4682e-01, -5.6222e-01, -5.5143e-01,  ..., -7.6140e-02,
#             1.0536e-02,  6.7244e-02]]],
#
#
#         [[[-4.9622e-01, -2.5862e-01, -8.3399e-02,  ...,  5.2142e-01,
#             4.6479e-01,  3.9439e-01],
#           [-4.0228e-01, -1.9091e-01, -3.7636e-02,  ...,  5.4524e-01,
#             5.0044e-01,  4.4711e-01],
#           [-2.7991e-01, -1.2130e-01,  1.4332e-02,  ...,  5.7336e-01,
#             5.2122e-01,  4.7301e-01],
#           ...,
#           [ 4.0766e-02,  2.0643e-01,  3.4633e-01,  ...,  6.5541e-01,
#             6.2006e-01,  5.8373e-01],
#           [-3.2558e-02,  1.3463e-01,  2.8481e-01,  ...,  6.3132e-01,
#             5.9552e-01,  5.6180e-01],
#           [-9.4111e-02,  7.9167e-02,  2.2707e-01,  ...,  6.1029e-01,
#             5.5599e-01,  5.3653e-01]],
#
#          [[-6.5427e-01, -4.5605e-01, -3.1700e-01,  ...,  3.4103e-01,
#             2.8439e-01,  2.1400e-01],
#           [-5.7164e-01, -3.9778e-01, -2.7402e-01,  ...,  3.6500e-01,
#             3.2021e-01,  2.6687e-01],
#           [-4.7385e-01, -3.4895e-01, -2.2485e-01,  ...,  3.9841e-01,
#             3.4627e-01,  2.9806e-01],
#           ...,
#           [-1.6619e-01,  4.6305e-03,  1.5548e-01,  ...,  4.9855e-01,
#             4.6320e-01,  4.2687e-01],
#           [-2.3352e-01, -6.2358e-02,  9.7677e-02,  ...,  4.7446e-01,
#             4.3866e-01,  4.0494e-01],
#           [-2.9008e-01, -1.1353e-01,  4.1362e-02,  ...,  4.5343e-01,
#             3.9913e-01,  3.7966e-01]],
#
#          [[-6.4501e-01, -4.9800e-01, -3.7268e-01,  ...,  4.8111e-01,
#             4.2448e-01,  3.5408e-01],
#           [-5.7145e-01, -4.2828e-01, -3.0126e-01,  ...,  4.9321e-01,
#             4.4842e-01,  3.9508e-01],
#           [-4.9290e-01, -3.6138e-01, -2.0910e-01,  ...,  5.0758e-01,
#             4.5543e-01,  4.0722e-01],
#           ...,
#           [-1.3571e-01,  5.9937e-02,  2.5513e-01,  ...,  5.6914e-01,
#             5.3379e-01,  4.9746e-01],
#           [-2.4156e-01, -3.6225e-02,  1.7942e-01,  ...,  5.4505e-01,
#             5.0924e-01,  4.7553e-01],
#           [-3.2792e-01, -1.1004e-01,  1.1449e-01,  ...,  5.2402e-01,
#             4.6972e-01,  4.5025e-01]]],
#
#
#         [[[ 2.7434e-01,  3.3136e-01,  3.8797e-01,  ...,  5.3208e-01,
#             5.2733e-01,  5.0309e-01],
#           [ 2.8511e-01,  3.4954e-01,  4.0620e-01,  ...,  5.4897e-01,
#             5.3021e-01,  5.0196e-01],
#           [ 2.7951e-01,  3.7175e-01,  4.2147e-01,  ...,  5.4326e-01,
#             5.1529e-01,  5.3888e-01],
#           ...,
#           [ 2.3380e-01,  3.1074e-01,  3.9444e-01,  ...,  5.2859e-01,
#             5.3134e-01,  5.3395e-01],
#           [ 2.0896e-01,  3.1319e-01,  3.8299e-01,  ...,  5.0178e-01,
#             5.0316e-01,  5.0625e-01],
#           [ 1.3737e-01,  2.1126e-01,  2.5854e-01,  ...,  2.8218e-01,
#             2.7896e-01,  2.7848e-01]],
#
#          [[ 9.0968e-02,  1.2881e-01,  1.8701e-01,  ...,  4.3198e-01,
#             3.9069e-01,  3.1981e-01],
#           [ 1.1075e-01,  1.5215e-01,  2.1128e-01,  ...,  4.6850e-01,
#             4.0864e-01,  3.3595e-01],
#           [ 1.1776e-01,  1.8873e-01,  2.4083e-01,  ...,  4.8053e-01,
#             4.1126e-01,  3.8895e-01],
#           ...,
#           [ 1.5341e-01,  1.9829e-01,  2.6982e-01,  ...,  5.2347e-01,
#             4.8910e-01,  4.5066e-01],
#           [ 1.4100e-01,  2.1407e-01,  2.6853e-01,  ...,  4.9540e-01,
#             4.5905e-01,  4.2158e-01],
#           [ 7.6330e-02,  1.2353e-01,  1.5864e-01,  ...,  2.7290e-01,
#             2.3358e-01,  1.9120e-01]],
#
#          [[-1.2190e-01, -9.8758e-02, -3.7855e-02,  ...,  3.4121e-01,
#             2.7051e-01,  1.5842e-01],
#           [-9.2683e-02, -6.5082e-02, -4.4736e-03,  ...,  3.3998e-01,
#             2.4874e-01,  1.3786e-01],
#           [-7.5109e-02, -1.9297e-02,  3.4125e-02,  ...,  3.3211e-01,
#             2.3205e-01,  1.7506e-01],
#           ...,
#           [ 5.1537e-03,  2.7268e-02,  8.5923e-02,  ...,  4.3265e-01,
#             3.5258e-01,  2.6678e-01],
#           [-8.3711e-05,  5.5475e-02,  1.0201e-01,  ...,  4.1903e-01,
#             3.3844e-01,  2.5463e-01],
#           [-5.7678e-02, -3.1587e-02, -7.7742e-03,  ...,  2.1142e-01,
#             1.2458e-01,  3.7309e-02]]],
#
#
#         [[[-1.5555e-01, -1.4357e-01, -1.4005e-01,  ..., -2.2241e-03,
#            -7.3896e-02, -1.0908e-01],
#           [-1.9693e-01, -1.5487e-01, -1.3018e-01,  ..., -1.5136e-02,
#            -7.6695e-02, -1.1113e-01],
#           [-2.0471e-01, -1.5800e-01, -1.2860e-01,  ...,  5.8639e-04,
#            -4.9755e-02, -8.3816e-02],
#           ...,
#           [-7.3765e-02, -7.9622e-02, -7.5003e-02,  ..., -1.2544e-01,
#            -1.7214e-01, -2.0738e-01],
#           [-9.7942e-02, -1.1492e-01, -9.8327e-02,  ..., -1.4251e-01,
#            -1.6399e-01, -2.0327e-01],
#           [-1.3629e-01, -1.4129e-01, -1.2170e-01,  ..., -1.5209e-01,
#            -1.6595e-01, -2.2070e-01]],
#
#          [[-4.7010e-01, -4.4152e-01, -4.2101e-01,  ..., -2.4536e-01,
#            -3.1703e-01, -3.5222e-01],
#           [-4.9808e-01, -4.4178e-01, -3.9753e-01,  ..., -2.5827e-01,
#            -3.1983e-01, -3.5426e-01],
#           [-4.8849e-01, -4.2385e-01, -3.7951e-01,  ..., -2.4255e-01,
#            -2.9289e-01, -3.2695e-01],
#           ...,
#           [-2.5416e-01, -2.6498e-01, -2.7620e-01,  ..., -3.5561e-01,
#            -4.1656e-01, -4.5107e-01],
#           [-2.7833e-01, -3.0028e-01, -2.9953e-01,  ..., -3.7268e-01,
#            -4.0841e-01, -4.4695e-01],
#           [-3.1668e-01, -3.2664e-01, -3.2290e-01,  ..., -3.8226e-01,
#            -4.1037e-01, -4.6438e-01]],
#
#          [[-3.4239e-01, -3.4801e-01, -3.3513e-01,  ..., -2.6377e-01,
#            -3.5129e-01, -3.9143e-01],
#           [-3.7331e-01, -3.5307e-01, -3.1680e-01,  ..., -2.7668e-01,
#            -3.5409e-01, -3.9348e-01],
#           [-3.7045e-01, -3.4334e-01, -3.0576e-01,  ..., -2.6096e-01,
#            -3.2715e-01, -3.6617e-01],
#           ...,
#           [-1.8339e-01, -2.1328e-01, -2.5155e-01,  ..., -3.4457e-01,
#            -4.1560e-01, -4.6511e-01],
#           [-2.0756e-01, -2.4857e-01, -2.7488e-01,  ..., -3.6164e-01,
#            -4.0745e-01, -4.6100e-01],
#           [-2.4591e-01, -2.7494e-01, -2.9825e-01,  ..., -3.7121e-01,
#            -4.0941e-01, -4.7842e-01]]],
#
#
#         [[[ 3.8669e-01,  4.7091e-01,  5.3353e-01,  ...,  3.0607e-01,
#             2.1850e-01,  1.1096e-01],
#           [ 4.4307e-01,  5.0223e-01,  5.6500e-01,  ...,  3.4557e-01,
#             2.5587e-01,  1.6089e-01],
#           [ 4.9707e-01,  5.5472e-01,  6.0124e-01,  ...,  3.7619e-01,
#             2.9752e-01,  2.1278e-01],
#           ...,
#           [-1.0596e-02,  8.6717e-02,  1.9926e-01,  ..., -4.2588e-02,
#            -1.8387e-01, -3.2575e-01],
#           [-7.8020e-02,  3.1253e-02,  1.2462e-01,  ..., -1.2419e-01,
#            -2.7443e-01, -4.2158e-01],
#           [-1.4880e-01, -3.8324e-02,  7.7990e-02,  ..., -2.0275e-01,
#            -3.6262e-01, -5.0839e-01]],
#
#          [[ 1.2377e-01,  2.0521e-01,  2.6705e-01,  ...,  2.6115e-02,
#            -5.6169e-02, -1.6355e-01],
#           [ 1.6866e-01,  2.2212e-01,  2.8329e-01,  ...,  6.5615e-02,
#            -1.8801e-02, -1.1362e-01],
#           [ 2.0372e-01,  2.5681e-01,  3.0097e-01,  ...,  9.6243e-02,
#             2.2855e-02, -6.1731e-02],
#           ...,
#           [-3.2432e-01, -2.3213e-01, -1.4072e-01,  ..., -3.0406e-01,
#            -4.2747e-01, -5.5920e-01],
#           [-3.9175e-01, -2.8759e-01, -2.1535e-01,  ..., -3.7123e-01,
#            -5.0732e-01, -6.3916e-01],
#           [-4.6253e-01, -3.5717e-01, -2.6199e-01,  ..., -4.3745e-01,
#            -5.8018e-01, -7.1380e-01]],
#
#          [[ 2.5847e-01,  3.5440e-01,  4.3078e-01,  ...,  2.2844e-01,
#             1.2918e-01,  1.0089e-02],
#           [ 3.0603e-01,  3.7690e-01,  4.5343e-01,  ...,  2.6794e-01,
#             1.6655e-01,  6.0022e-02],
#           [ 3.4786e-01,  4.1723e-01,  4.7752e-01,  ...,  2.9856e-01,
#             2.0821e-01,  1.1191e-01],
#           ...,
#           [-2.3805e-01, -1.4329e-01, -4.1318e-02,  ..., -2.4956e-01,
#            -3.9282e-01, -5.4196e-01],
#           [-3.0547e-01, -1.9876e-01, -1.1595e-01,  ..., -3.2146e-01,
#            -4.7614e-01, -6.2566e-01],
#           [-3.7625e-01, -2.6834e-01, -1.6259e-01,  ..., -3.9377e-01,
#            -5.5507e-01, -7.0437e-01]]]]), 'label': tensor([1, 0, 1, 0, 1])}
# torch.Size([5, 3, 64, 64])
# tensor([1, 0, 1, 0, 1])
# {'image': tensor([[[[-0.9725, -0.9066, -0.7586,  ...,  0.3544,  0.2691,  0.1696],
#           [-0.9204, -0.8044, -0.6135,  ...,  0.4268,  0.3491,  0.2625],
#           [-0.8105, -0.6433, -0.4283,  ...,  0.4807,  0.4329,  0.3597],
#           ...,
#           [-0.9671, -0.9564, -0.8851,  ...,  0.3040,  0.2048,  0.0874],
#           [-0.9818, -0.9812, -0.9579,  ...,  0.1808,  0.0634, -0.0620],
#           [-0.9843, -0.9844, -0.9810,  ...,  0.0507, -0.0843, -0.2343]],
#
#          [[-0.9591, -0.9106, -0.7966,  ...,  0.3152,  0.2299,  0.1304],
#           [-0.9252, -0.8282, -0.6747,  ...,  0.3876,  0.3099,  0.2233],
#           [-0.8485, -0.7072, -0.5297,  ...,  0.4414,  0.3937,  0.3205],
#           ...,
#           [-0.9837, -0.9755, -0.9061,  ...,  0.2713,  0.1734,  0.0562],
#           [-0.9865, -0.9860, -0.9627,  ...,  0.1494,  0.0340, -0.0882],
#           [-0.9843, -0.9844, -0.9810,  ...,  0.0194, -0.1105, -0.2579]],
#
#          [[-0.9545, -0.8890, -0.7477,  ...,  0.5662,  0.4809,  0.3814],
#           [-0.9012, -0.7894, -0.6116,  ...,  0.6386,  0.5609,  0.4742],
#           [-0.7996, -0.6427, -0.4353,  ...,  0.6924,  0.6447,  0.5715],
#           ...,
#           [-0.9849, -0.9629, -0.8711,  ...,  0.4818,  0.3660,  0.2400],
#           [-0.9827, -0.9821, -0.9559,  ...,  0.3420,  0.2124,  0.0818],
#           [-0.9768, -0.9844, -0.9857,  ...,  0.2033,  0.0579, -0.1006]]],
#
#
#         [[[-0.5854, -0.3741, -0.2271,  ...,  0.4105,  0.3962,  0.3079],
#           [-0.5183, -0.3522, -0.1698,  ...,  0.4279,  0.4127,  0.3289],
#           [-0.4546, -0.2951, -0.1033,  ...,  0.4703,  0.4313,  0.3498],
#           ...,
#           [-0.1601, -0.0064,  0.1724,  ...,  0.4808,  0.4486,  0.4153],
#           [-0.2087, -0.0344,  0.1545,  ...,  0.4648,  0.4570,  0.4257],
#           [-0.1868, -0.0428,  0.0718,  ...,  0.4644,  0.4592,  0.4141]],
#
#          [[-0.7414, -0.6247, -0.5558,  ...,  0.1449,  0.1341,  0.0516],
#           [-0.7033, -0.6122, -0.4875,  ...,  0.1551,  0.1418,  0.0638],
#           [-0.6818, -0.5576, -0.3950,  ...,  0.1823,  0.1459,  0.0711],
#           ...,
#           [-0.4322, -0.2835, -0.0949,  ...,  0.1671,  0.1348,  0.1016],
#           [-0.4783, -0.3079, -0.1080,  ...,  0.1510,  0.1433,  0.1120],
#           [-0.4550, -0.3140, -0.1896,  ...,  0.1507,  0.1455,  0.1004]],
#
#          [[-0.6779, -0.5744, -0.4611,  ...,  0.4004,  0.3774,  0.2577],
#           [-0.6339, -0.5453, -0.3726,  ...,  0.4084,  0.3814,  0.2661],
#           [-0.6028, -0.4630, -0.2511,  ...,  0.4291,  0.3756,  0.2664],
#           ...,
#           [-0.2761, -0.0728,  0.1546,  ...,  0.3788,  0.3466,  0.3134],
#           [-0.3376, -0.1146,  0.1248,  ...,  0.3628,  0.3551,  0.3237],
#           [-0.3266, -0.1326,  0.0318,  ...,  0.3625,  0.3573,  0.3121]]],
#
#
#         [[[ 0.3094,  0.3683,  0.4265,  ...,  0.5714,  0.5282,  0.5059],
#           [ 0.2992,  0.3499,  0.4249,  ...,  0.5936,  0.5578,  0.4728],
#           [ 0.3484,  0.3734,  0.4133,  ...,  0.5895,  0.5481,  0.4860],
#           ...,
#           [ 0.2510,  0.3206,  0.3617,  ...,  0.3846,  0.3770,  0.3779],
#           [ 0.2392,  0.3207,  0.3387,  ...,  0.3858,  0.3323,  0.3229],
#           [ 0.2074,  0.2659,  0.2998,  ...,  0.3749,  0.3416,  0.2933]],
#
#          [[-0.1387, -0.0821, -0.0306,  ...,  0.1662,  0.1040,  0.0746],
#           [-0.1607, -0.1106, -0.0410,  ...,  0.1885,  0.1344,  0.0438],
#           [-0.1252, -0.1003, -0.0620,  ...,  0.1841,  0.1287,  0.0632],
#           ...,
#           [-0.1411, -0.0693, -0.0246,  ..., -0.0418, -0.0372, -0.0372],
#           [-0.1530, -0.0725, -0.0538,  ..., -0.0407, -0.0820, -0.0922],
#           [-0.1851, -0.1317, -0.0979,  ..., -0.0515, -0.0726, -0.1218]],
#
#          [[-0.2191, -0.1365, -0.0420,  ...,  0.1808,  0.1353,  0.1127],
#           [-0.2203, -0.1531, -0.0543,  ...,  0.2039,  0.1554,  0.0634],
#           [-0.1527, -0.1217, -0.0717,  ...,  0.2072,  0.1334,  0.0523],
#           ...,
#           [-0.2112, -0.1570, -0.1337,  ..., -0.1329, -0.1166, -0.1016],
#           [-0.2283, -0.1318, -0.1198,  ..., -0.1317, -0.1614, -0.1566],
#           [-0.2614, -0.1721, -0.1364,  ..., -0.1426, -0.1520, -0.1862]]],
#
#
#         [[[-0.7322, -0.7395, -0.7015,  ..., -0.3057, -0.2890, -0.4037],
#           [-0.7846, -0.7684, -0.7387,  ..., -0.2371, -0.2818, -0.3225],
#           [-0.7836, -0.7464, -0.7685,  ..., -0.2597, -0.2961, -0.2771],
#           ...,
#           [ 0.1852,  0.2034,  0.2646,  ...,  0.2773,  0.3327,  0.2884],
#           [ 0.2103,  0.1596,  0.1017,  ...,  0.3186,  0.3012,  0.2150],
#           [-0.3020, -0.3828, -0.2577,  ...,  0.3251,  0.2213,  0.0241]],
#
#          [[-0.8107, -0.8180, -0.7799,  ..., -0.3849, -0.3734, -0.4854],
#           [-0.8630, -0.8468, -0.8172,  ..., -0.3163, -0.3661, -0.4042],
#           [-0.8621, -0.8249, -0.8466,  ..., -0.3389, -0.3805, -0.3588],
#           ...,
#           [ 0.1165,  0.1249,  0.1720,  ...,  0.2793,  0.3294,  0.2668],
#           [ 0.1314,  0.0743,  0.0049,  ...,  0.3487,  0.3162,  0.1783],
#           [-0.3900, -0.4715, -0.3564,  ...,  0.3715,  0.2481, -0.0120]],
#
#          [[-0.8264, -0.8334, -0.7955,  ..., -0.3251, -0.3478, -0.5372],
#           [-0.8787, -0.8622, -0.8326,  ..., -0.2564, -0.3405, -0.4560],
#           [-0.8777, -0.8404, -0.8613,  ..., -0.2791, -0.3549, -0.4106],
#           ...,
#           [ 0.1495,  0.1604,  0.2000,  ...,  0.3781,  0.4090,  0.3219],
#           [ 0.1361,  0.0509, -0.0382,  ...,  0.4524,  0.3727,  0.1802],
#           [-0.3952, -0.5263, -0.4421,  ...,  0.4579,  0.2685, -0.0732]]],
#
#
#         [[[ 0.3677,  0.4091,  0.4415,  ...,  0.3801,  0.2926,  0.2329],
#           [ 0.3616,  0.3971,  0.4246,  ...,  0.3912,  0.3193,  0.2561],
#           [ 0.3758,  0.3910,  0.4200,  ...,  0.4031,  0.3339,  0.2867],
#           ...,
#           [ 0.1712,  0.2336,  0.1986,  ...,  0.2394,  0.1413,  0.0665],
#           [ 0.1355,  0.2097,  0.2497,  ...,  0.0718,  0.0682,  0.0359],
#           [ 0.1127,  0.2101,  0.2531,  ...,  0.0645, -0.1029, -0.1268]],
#
#          [[-0.2798, -0.2502, -0.2334,  ..., -0.1669, -0.2216, -0.2623],
#           [-0.2751, -0.2495, -0.2415,  ..., -0.1557, -0.1949, -0.2391],
#           [-0.2433, -0.2379, -0.2276,  ..., -0.1438, -0.1802, -0.2085],
#           ...,
#           [-0.4092, -0.3540, -0.4080,  ..., -0.2213, -0.2874, -0.3417],
#           [-0.4449, -0.3779, -0.3570,  ..., -0.3731, -0.3441, -0.3579],
#           [-0.4677, -0.3775, -0.3535,  ..., -0.3679, -0.5054, -0.5065]],
#
#          [[-0.0972, -0.0617, -0.0386,  ...,  0.0188, -0.0480, -0.0971],
#           [-0.0968, -0.0671, -0.0500,  ...,  0.0300, -0.0214, -0.0739],
#           [-0.0704, -0.0621, -0.0447,  ...,  0.0419, -0.0067, -0.0433],
#           ...,
#           [-0.2759, -0.2183, -0.2654,  ..., -0.1628, -0.2390, -0.2987],
#           [-0.3115, -0.2421, -0.2144,  ..., -0.3197, -0.3007, -0.3217],
#           [-0.3344, -0.2418, -0.2109,  ..., -0.3185, -0.4652, -0.4764]]]]), 'label': tensor([1, 0, 0, 0, 0])}
# torch.Size([5, 3, 64, 64])
# tensor([1, 0, 0, 0, 0])
# {'image': tensor([[[[-0.9152, -0.8247, -0.6732,  ..., -0.8750, -0.9354, -0.9546],
#           [-0.8078, -0.6613, -0.5037,  ..., -0.7417, -0.8748, -0.9373],
#           [-0.6450, -0.4922, -0.3400,  ..., -0.5661, -0.7436, -0.8721],
#           ...,
#           [-0.1060,  0.0186,  0.1181,  ...,  0.0597, -0.1082, -0.2818],
#           [-0.2522, -0.1108,  0.0124,  ..., -0.1001, -0.2892, -0.4564],
#           [-0.3790, -0.2291, -0.0932,  ..., -0.2572, -0.4479, -0.6262]],
#
#          [[-0.9074, -0.8169, -0.6653,  ..., -0.8750, -0.9354, -0.9546],
#           [-0.7999, -0.6534, -0.4959,  ..., -0.7417, -0.8748, -0.9373],
#           [-0.6372, -0.4843, -0.3321,  ..., -0.5661, -0.7436, -0.8721],
#           ...,
#           [-0.1217,  0.0029,  0.1024,  ...,  0.0910, -0.0769, -0.2505],
#           [-0.2679, -0.1265, -0.0033,  ..., -0.0687, -0.2578, -0.4250],
#           [-0.3947, -0.2448, -0.1089,  ..., -0.2258, -0.4165, -0.5948]],
#
#          [[-0.8917, -0.7962, -0.6288,  ..., -0.8750, -0.9354, -0.9546],
#           [-0.7842, -0.6328, -0.4594,  ..., -0.7417, -0.8748, -0.9373],
#           [-0.6215, -0.4637, -0.2956,  ..., -0.5661, -0.7436, -0.8721],
#           ...,
#           [-0.1139,  0.0108,  0.1103,  ...,  0.1146, -0.0533, -0.2269],
#           [-0.2600, -0.1187,  0.0045,  ..., -0.0452, -0.2343, -0.4015],
#           [-0.3868, -0.2369, -0.1010,  ..., -0.2023, -0.3930, -0.5713]]],
#
#
#         [[[-1.0000, -1.0000, -1.0000,  ..., -0.9968, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -0.9857, -0.9992, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -0.9627, -0.9911, -0.9991],
#           ...,
#           [-0.9982, -0.9887, -0.9518,  ..., -0.9945, -0.9969, -1.0000],
#           [-1.0000, -0.9988, -0.9836,  ..., -0.9963, -0.9998, -1.0000],
#           [-1.0000, -1.0000, -0.9981,  ..., -0.9998, -1.0000, -1.0000]],
#
#          [[-1.0000, -1.0000, -1.0000,  ..., -0.9976, -0.9934, -0.9922],
#           [-1.0000, -1.0000, -1.0000,  ..., -0.9967, -0.9964, -0.9926],
#           [-1.0000, -1.0000, -1.0000,  ..., -0.9874, -0.9987, -0.9980],
#           ...,
#           [-0.9974, -0.9982, -0.9758,  ..., -0.9945, -0.9969, -1.0000],
#           [-0.9924, -0.9956, -0.9935,  ..., -0.9963, -0.9998, -1.0000],
#           [-0.9922, -0.9934, -0.9981,  ..., -0.9998, -1.0000, -1.0000]],
#
#          [[-1.0000, -1.0000, -1.0000,  ..., -0.9979, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -0.9921, -0.9998, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -0.9801, -0.9969, -1.0000],
#           ...,
#           [-0.9993, -0.9952, -0.9692,  ..., -0.9945, -0.9969, -1.0000],
#           [-1.0000, -0.9997, -0.9901,  ..., -0.9963, -0.9998, -1.0000],
#           [-1.0000, -1.0000, -0.9991,  ..., -0.9998, -1.0000, -1.0000]]],
#
#
#         [[[ 0.3455,  0.3972,  0.4521,  ...,  0.5715,  0.5062,  0.4874],
#           [ 0.3624,  0.4208,  0.4439,  ...,  0.5847,  0.5425,  0.5239],
#           [ 0.3687,  0.4108,  0.4321,  ...,  0.6057,  0.5612,  0.5339],
#           ...,
#           [ 0.3135,  0.3659,  0.4098,  ...,  0.5370,  0.4800,  0.3849],
#           [ 0.2732,  0.3515,  0.3841,  ...,  0.4846,  0.4238,  0.3219],
#           [ 0.2094,  0.2915,  0.3515,  ...,  0.4544,  0.3861,  0.3003]],
#
#          [[ 0.0714,  0.1100,  0.1515,  ...,  0.2876,  0.2238,  0.2050],
#           [ 0.0912,  0.1343,  0.1466,  ...,  0.3007,  0.2602,  0.2415],
#           [ 0.0994,  0.1288,  0.1375,  ...,  0.3217,  0.2788,  0.2515],
#           ...,
#           [ 0.0468,  0.0993,  0.1448,  ...,  0.2360,  0.1808,  0.0869],
#           [ 0.0065,  0.0849,  0.1190,  ...,  0.1856,  0.1291,  0.0306],
#           [-0.0573,  0.0248,  0.0864,  ...,  0.1566,  0.0946,  0.0122]],
#
#          [[ 0.1761,  0.2056,  0.2362,  ...,  0.1934,  0.1111,  0.0806],
#           [ 0.1813,  0.2197,  0.2183,  ...,  0.2066,  0.1475,  0.1171],
#           [ 0.1717,  0.1936,  0.1966,  ...,  0.2276,  0.1661,  0.1271],
#           ...,
#           [ 0.0536,  0.0944,  0.1267,  ...,  0.1685,  0.1001, -0.0017],
#           [ 0.0133,  0.0801,  0.1009,  ...,  0.1056,  0.0157, -0.1025],
#           [-0.0505,  0.0200,  0.0683,  ...,  0.0698, -0.0379, -0.1417]]],
#
#
#         [[[ 0.1357,  0.1098,  0.0983,  ...,  0.0922,  0.0959,  0.0914],
#           [ 0.1243,  0.0904,  0.0833,  ...,  0.0948,  0.1139,  0.1220],
#           [ 0.1472,  0.1284,  0.1246,  ...,  0.0848,  0.0972,  0.1039],
#           ...,
#           [ 0.0853,  0.0852,  0.0814,  ...,  0.0616,  0.0579,  0.0534],
#           [ 0.0797,  0.0797,  0.0870,  ...,  0.0554,  0.0776,  0.0794],
#           [ 0.0924,  0.0926,  0.1022,  ...,  0.0651,  0.0954,  0.1089]],
#
#          [[-0.0196, -0.0690, -0.1231,  ..., -0.1458, -0.1580, -0.1674],
#           [-0.0272, -0.0784, -0.1175,  ..., -0.1432, -0.1399, -0.1368],
#           [ 0.0050, -0.0217, -0.0355,  ..., -0.1533, -0.1566, -0.1549],
#           ...,
#           [-0.0629, -0.0626, -0.0666,  ..., -0.1429, -0.1508, -0.1561],
#           [-0.0331, -0.0330, -0.0257,  ..., -0.1668, -0.1500, -0.1508],
#           [-0.0028, -0.0026,  0.0070,  ..., -0.1677, -0.1439, -0.1332]],
#
#          [[ 0.0059, -0.0346, -0.0754,  ..., -0.0829, -0.0898, -0.0968],
#           [ 0.0103, -0.0331, -0.0612,  ..., -0.0803, -0.0718, -0.0663],
#           [ 0.0551,  0.0304,  0.0211,  ..., -0.0904, -0.0884, -0.0843],
#           ...,
#           [-0.0693, -0.0691, -0.0731,  ..., -0.1672, -0.1587, -0.1613],
#           [-0.0333, -0.0332, -0.0259,  ..., -0.1858, -0.1373, -0.1221],
#           [-0.0028, -0.0026,  0.0070,  ..., -0.1841, -0.1176, -0.0837]]],
#
#
#         [[[ 0.0871,  0.1199,  0.2024,  ...,  0.0887,  0.0529,  0.0355],
#           [ 0.1417,  0.1604,  0.1948,  ...,  0.1401,  0.0790,  0.0123],
#           [ 0.1558,  0.1961,  0.1397,  ...,  0.1399,  0.0823,  0.0661],
#           ...,
#           [ 0.1891,  0.2253,  0.2758,  ...,  0.1735,  0.1624,  0.1802],
#           [ 0.1942,  0.2146,  0.2746,  ...,  0.1500,  0.1604,  0.1442],
#           [ 0.1969,  0.2115,  0.2743,  ...,  0.1769,  0.1458,  0.1346]],
#
#          [[-0.0292, -0.0167,  0.0402,  ..., -0.0914, -0.1107, -0.1185],
#           [ 0.0199,  0.0132,  0.0123,  ..., -0.0660, -0.1110, -0.1684],
#           [ 0.0280,  0.0315, -0.0788,  ..., -0.0637, -0.1078, -0.1147],
#           ...,
#           [-0.0058,  0.0689,  0.1473,  ...,  0.0534,  0.0422,  0.0601],
#           [-0.0145,  0.0594,  0.1639,  ...,  0.0175,  0.0277,  0.0118],
#           [-0.0191,  0.0574,  0.1739,  ...,  0.0074, -0.0238, -0.0348]],
#
#          [[ 0.1052,  0.1249,  0.1891,  ...,  0.0022, -0.0148, -0.0170],
#           [ 0.1442,  0.1449,  0.1570,  ...,  0.0421,  0.0035, -0.0435],
#           [ 0.1375,  0.1546,  0.0629,  ...,  0.0565,  0.0273,  0.0270],
#           ...,
#           [ 0.0944,  0.1558,  0.2250,  ...,  0.0772,  0.0660,  0.0838],
#           [ 0.1043,  0.1603,  0.2491,  ...,  0.0445,  0.0548,  0.0388],
#           [ 0.1155,  0.1707,  0.2689,  ...,  0.0492,  0.0180,  0.0069]]]]), 'label': tensor([1, 1, 0, 1, 1])}
# torch.Size([5, 3, 64, 64])
# tensor([1, 1, 0, 1, 1])

# %% [markdown]
# ## Definición del modelo

# %%
class InterpretableConvLayer(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, feature_map_size, tau=0.5, beta=4.0, alpha=0.95):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, padding=1, bias=True)
        self.tau = tau
        self.beta = beta
        self.alpha = alpha
        self.n = feature_map_size
        self.templates = generate_templates(self.n, tau=self.tau, beta=self.beta)

    def forward(self, x):
        x = nn.ReLU()(self.conv(x))
        if not self.training:
            logging.info("Training mode: applying masks to feature maps.")
            masks = self._assign_masks(x)
            masked_x = x * masks
            return masked_x * (masked_x > 0)
        else:
            logging.info("Inference mode: applying templates to feature maps.")
            return x

    def _assign_masks(self, x):

        B, C, H, W = x.shape

        x_flat = x.view(B * C, H, W)
        masks = []

        for fmap in x_flat:
            mu_hat = torch.argmax(fmap.view(-1))
            i, j = mu_hat // self.n, mu_hat % self.n
            idx = i * self.n + j
            mask = self.templates[idx]
            masks.append(mask)

        masks = torch.stack(masks).view(B, C, H, W).to(x.device)
        return masks

# %%
OUTPUT_CHANNELS = len(classes)
INPUT_CHANNELS = X.shape[1]
icnn = InterpretableConvLayer(in_channels=INPUT_CHANNELS, out_channels=OUTPUT_CHANNELS, kernel_size=3, feature_map_size=n, tau=(0.5/(n*n)), beta=4.0)
icnn = icnn.to(device)
icnn
# Out:
# InterpretableConvLayer(
#   (conv): Conv2d(2, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
output = icnn(X.to(device))
output.shape
# Out:
# torch.Size([5, 2, 16, 16])

# %%
class Model(nn.Module):
    def __init__(self, feature_map_size, channels=1, num_classes=10, filters_icnn=6):
        super().__init__()
        filters_cnn=20
        self.cnn = nn.Conv2d(channels, filters_cnn, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.icnn = InterpretableConvLayer(in_channels=filters_cnn, out_channels=filters_icnn, kernel_size=3, feature_map_size=feature_map_size//2, tau=2.00, beta=4.00, alpha=4.00)
        # self.cnn2 = nn.Conv2d(filters_cnn, filters_icnn, kernel_size=3, padding=1)

        input_size = filters_icnn * (feature_map_size // 4) * (feature_map_size // 4)
        self.linear = nn.Linear(3072, 100)
        self.classifier = nn.Linear(100, num_classes)

    def forward(self, x):
        x = self.cnn(x)
        x = self.pool(x)
        x = nn.ReLU()(x)
        x = self.icnn(x)
        # x = self.cnn2(x)
        x = nn.ReLU()(x)
        icnn_output = x
        x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        x = nn.ReLU()(x)
        logits = self.classifier(x)
        # x = torch.softmax(x, dim=1)
        return logits, icnn_output

# %% [markdown]
# ## Training

# %%
INPUT_CHANNELS = 3

# %%
n = trainset[0]['image'].shape[-1]
print("Feature map size n =", n)
model = Model(feature_map_size=n, channels=INPUT_CHANNELS, num_classes=len(classes), filters_icnn=12)
# Out:
# Feature map size n = 64

# %%
trainset[0]['image'].unsqueeze(0).shape
# Out:
# torch.Size([1, 3, 64, 64])

# %% [markdown]
# ## Entrenamiento del modelo

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=3e-1)
criterion = nn.CrossEntropyLoss()

# %%
n
# Out:
# 64

# %%
lambda_ = 1e-2
EPOCHS = 40

losses = {
    "total_loss": [],
    "class_loss": [],
    "interp_loss": []
}

model = Model(feature_map_size=n, channels=3, num_classes=len(classes), filters_icnn=12)
model = model.to(device)
model.train()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-3)
criterion = nn.CrossEntropyLoss()

# keep_icnn_output = 0
# keep_templates = 0
for epoch in trange(EPOCHS):
    losses_epoch = {
        "total_loss": [],
        "class_loss": [],
        "interp_loss": []
    }
    for batch in tqdm(trainloader, desc="Training", leave=False):

        optimizer.zero_grad()
        images, labels = batch['image'].to(device), batch['label'].to(device)
        logits, icnn_output = model(images)

        # print(y_pred.shape, labels.shape)
        # print(labels, "labels")
        # print(y_pred, "y pred")
        class_loss = criterion(logits, labels.long())
        # print(y_pred)


        # batch_size = images.shape[0]
        # templates = model.icnn.templates.unsqueeze(0).to(device)

        # keep_icnn_output = icnn_output.detach().clone()
        # keep_templates = templates.detach().clone()

        # print("icnn output", icnn_output.shape)
        # print("templates", templates.shape)
        interp_loss = mutual_information(icnn_output, templates, icnn_output.shape[-1], device=device).sum()
        total_loss = lambda_ * interp_loss + (1 - lambda_) * class_loss
        # total_loss = class_loss
        # print("Interp loss", lambda_ * interp_loss.item())
        # print("Total loss", total_loss.item())

        # losses["class_loss"].append(class_loss.item())
        losses_epoch["class_loss"].append(class_loss.item())

        class_loss.backward()
        optimizer.step()
        # break

    avg_loss = np.mean(losses_epoch["class_loss"])
    print(f"Epoch {epoch+1}/{EPOCHS}, Avg Class Loss: {avg_loss:.4f}")
    # avg_interp_loss = np.mean(losses_epoch["interp_loss
    # print(np.mean(losses["class_loss"]))
    print(class_loss)
    # print(interp_loss)
    # losses["total_loss"].append(total_loss.item())
    losses["class_loss"].append(avg_loss)
    # losses["interp_loss"].append(interp_loss.item())
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 1/40, Avg Class Loss: 0.3917
# tensor(0.1133, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 2/40, Avg Class Loss: 0.3314
# tensor(0.1621, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 3/40, Avg Class Loss: 0.3142
# tensor(0.1534, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 4/40, Avg Class Loss: 0.3027
# tensor(0.0409, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 5/40, Avg Class Loss: 0.2911
# tensor(0.0085, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 6/40, Avg Class Loss: 0.2839
# tensor(0.0498, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 7/40, Avg Class Loss: 0.2759
# tensor(0.0962, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 8/40, Avg Class Loss: 0.2684
# tensor(0.2065, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 9/40, Avg Class Loss: 0.2553
# tensor(0.0103, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 10/40, Avg Class Loss: 0.2507
# tensor(0.0278, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 11/40, Avg Class Loss: 0.2409
# tensor(0.0201, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 12/40, Avg Class Loss: 0.2345
# tensor(0.2332, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 13/40, Avg Class Loss: 0.2271
# tensor(0.3095, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 14/40, Avg Class Loss: 0.2170
# tensor(0.0075, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 15/40, Avg Class Loss: 0.2115
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 16/40, Avg Class Loss: 0.2089
# tensor(0.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 17/40, Avg Class Loss: 0.1976
# tensor(0.0696, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 18/40, Avg Class Loss: 0.1937
# tensor(0.1869, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 19/40, Avg Class Loss: 0.1891
# tensor(0.0173, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 20/40, Avg Class Loss: 0.1816
# tensor(0.3259, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 21/40, Avg Class Loss: 0.1763
# tensor(-0., device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 22/40, Avg Class Loss: 0.1724
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 23/40, Avg Class Loss: 0.1679
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 24/40, Avg Class Loss: 0.1609
# tensor(8.8688e-05, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 25/40, Avg Class Loss: 0.1625
# tensor(0.0002, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 26/40, Avg Class Loss: 0.1508
# tensor(2.3842e-07, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 27/40, Avg Class Loss: 0.1475
# tensor(0.0004, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 28/40, Avg Class Loss: 0.1417
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 29/40, Avg Class Loss: 0.1368
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 30/40, Avg Class Loss: 0.1362
# tensor(3.1948e-05, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 31/40, Avg Class Loss: 0.1356
# tensor(0.0001, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 32/40, Avg Class Loss: 0.1333
# tensor(0.0413, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 33/40, Avg Class Loss: 0.1282
# tensor(0.0100, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 34/40, Avg Class Loss: 0.1245
# tensor(1.1921e-07, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 35/40, Avg Class Loss: 0.1228
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 36/40, Avg Class Loss: 0.1225
# tensor(0.0259, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 37/40, Avg Class Loss: 0.1184
# tensor(0.0005, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 38/40, Avg Class Loss: 0.1124
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 39/40, Avg Class Loss: 0.1159
# tensor(0.0144, device='mps:0', grad_fn=<NllLossBackward0>)
# Training:   0%|          | 0/2139 [00:00<?, ?it/s]
# Epoch 40/40, Avg Class Loss: 0.1133
# tensor(0.0507, device='mps:0', grad_fn=<NllLossBackward0>)

# %%
# plt.plot(losses["total_loss"], label="Total Loss")
plt.plot(losses["class_loss"], label="Class Loss")
# plt.plot(losses["interp_loss"], label="Interp Loss")

# %%
rand_i = random.randint(0, len(testset)-1)
rand_item = testset[rand_i]["image"].unsqueeze(0)
rand_item.shape
plot_tensors(rand_item, title="Random Test Image", cmap="gray", show_colorbar=False)

# %%
icnn_filters = model.icnn.conv.weight.data
icnn_filters.shape
# Out:
# torch.Size([12, 20, 3, 3])

# %%
logits, icnn_output = model(rand_item.to(device))
icnn_output.shape
# Out:
# torch.Size([1, 12, 32, 32])

# %%
plot_tensors(icnn_output)
# Out:
# /var/folders/sx/_3f9ftxx24q3hbz_25d1xrjh0000gn/T/ipykernel_77700/2983223761.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 0.95])

# %%
# Evaluate
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for batch in testloader:
        images, labels = batch['image'].to(device), batch['label'].to(device)
        outputs, _ = model(images)
        _, predicted = torch.max(outputs.data, 1)
        # print(predicted)
        # print(labels)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Accuracy of the model on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# Accuracy of the model on the 1188 test images: 74.66329966329967 %

# %% [markdown]
# ### Model without ICNN

# %%
class Model(nn.Module):
    def __init__(self, feature_map_size, channels=1, num_classes=10, filters_icnn=6):
        super().__init__()
        filters_cnn=20
        self.cnn = nn.Conv2d(channels, filters_cnn, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.icnn = nn.Conv2d(in_channels=filters_cnn, out_channels=filters_icnn, kernel_size=3, padding=1)
        # self.cnn2 = nn.Conv2d(filters_cnn, filters_icnn, kernel_size=3, padding=1)

        input_size = filters_icnn * (feature_map_size // 4) * (feature_map_size // 4)
        self.linear = nn.Linear(3072, 100)
        self.classifier = nn.Linear(100, num_classes)

    def forward(self, x):
        x = self.cnn(x)
        x = self.pool(x)
        x = nn.ReLU()(x)
        x = self.icnn(x)
        # x = self.cnn2(x)
        x = nn.ReLU()(x)
        icnn_output = x
        x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        x = nn.ReLU()(x)
        logits = self.classifier(x)
        # x = torch.softmax(x, dim=1)
        return logits, icnn_output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class Model(nn.Module):
#       2     def __init__(self, feature_map_size, channels=1, num_classes=10, filters_icnn=6):
#       3         super().__init__()
#
# NameError: name 'nn' is not defined
